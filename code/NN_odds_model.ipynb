# %%
# !pip install wordninja
# !pip install num2words

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers
from sklearn import preprocessing
import wordninja
from nltk.tokenize import RegexpTokenizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import re
import num2words
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

pd.set_option('display.max_columns', None)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordninja in /usr/local/lib/python3.8/dist-packages (2.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: num2words in /usr/local/lib/python3.8/dist-packages (0.5.12)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.8/dist-packages (from num2words) (0.6.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Specify the path to our shared drive. Should work for all of us.
path = '/content/drive/Shareddrives/ANLY590_GROUP_4_PROJECT'

# %%
df = pd.read_csv(path + "/data/merged_data/joined_data_without_position.csv", index_col=0)

# %%
df.head()
# Out:
#   track_id   race_date  race_number program_number  weight_carried  \
# 0      AQU  2019-01-01            1              1             123
# 1      AQU  2019-01-01            1              2             120
# 2      AQU  2019-01-01            1              3             118
# 3      AQU  2019-01-01            1              4             123
# 4      AQU  2019-01-01            1              5             118
#
#             jockey  odds  position_at_finish  distance_id course_type  \
# 0      Dylan Davis   130                   2          650           D
# 1  Junior Alvarado   295                   3          650           D
# 2     Jose Lezcano   180                   4          650           D
# 3     Jomar Garcia  1280                   5          650           D
# 4    Manuel Franco  1150                   1          650           D
#
#   track_condition  run_up_distance race_type  purse  post_time  \
# 0             MY                36       AOC  80000       1220
# 1             MY                36       AOC  80000       1220
# 2             MY                36       AOC  80000       1220
# 3             MY                36       AOC  80000       1220
# 4             MY                36       AOC  80000       1220
#
#   last_race_track day_since_last_race              Comments  seconds_in_race  \
# 0             AQU             37 days  ins,drve5/16,outlate             79.0
# 1             AQU             25 days  torail1/2,6p1/8,mild             79.0
# 2             AQU             37 days     prompted2w,folded             79.0
# 3             PRX             17 days     3wturn,alter5p1/8             79.0
# 4             AQU             37 days   3-4w,drve5/16,4w,up             79.0
#
#    humidity  precipcover  precip  temp  maxt  cloudcover  \
# 0     73.59        20.83     0.3  50.5  59.1        67.6
# 1     73.59        20.83     0.3  50.5  59.1        67.6
# 2     73.59        20.83     0.3  50.5  59.1        67.6
# 3     73.59        20.83     0.3  50.5  59.1        67.6
# 4     73.59        20.83     0.3  50.5  59.1        67.6
#
#                                weathertype  snow
# 0  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0
# 1  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0
# 2  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0
# 3  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0
# 4  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0

# %% [markdown]
# ## Preprocessing

# %%
# Create win dummy variable.
df['win'] = np.where(df['race_number'] >= 3, 1, 0)

# Drop the redundant variables.
df = df.drop(['position_at_finish', 'post_time', 'distance_id'], axis = 1)

# Convert the race number as string.
df['race_number'] = df['race_number'].astype('str')

# Convert to float and fill NA
df['day_since_last_race'] = df['day_since_last_race'].apply(lambda x : x[:-5] if x is not np.nan else np.nan).astype('float').fillna(0)

# Fill the comments column with string None.
df['Comments'] = df['Comments'].fillna('None')

# %%
# Preprocess the comments. 
res = []
tokenizer = RegexpTokenizer(r'\w+')
for i in df.Comments:
  if type(i) == str:
    re.sub(r"(\d+)", lambda x: num2words.num2words(int(x.group(0))), i)
    phrase_list = tokenizer.tokenize(i)
    splited_tokens = [wordninja.split(i) for i in phrase_list]
    flat_splited_tokens = [j for sublist in splited_tokens for j in sublist]
    res.append(flat_splited_tokens)    
  else:
    res.append(np.nan)

df['Comments'] = res

# %%
# Convert all numerical columns to float.
for i in df.columns:
  if df[i].dtype == int:
    df[i] = df[i].astype('float')

# %% [markdown]
# Here I concat all three outcome variables, so when training, be mindful about the column index

# %%
# Separate the target data and others.
target = df[['odds']]
data = df.drop(['win', 'odds', 'purse','Comments', "seconds_in_race", "race_number", "race_date"], axis = 1)

# %%
data.head()
# Out:
#   track_id program_number  weight_carried           jockey course_type  \
# 0      AQU              1           123.0      Dylan Davis           D
# 1      AQU              2           120.0  Junior Alvarado           D
# 2      AQU              3           118.0     Jose Lezcano           D
# 3      AQU              4           123.0     Jomar Garcia           D
# 4      AQU              5           118.0    Manuel Franco           D
#
#   track_condition  run_up_distance race_type last_race_track  \
# 0             MY              36.0       AOC             AQU
# 1             MY              36.0       AOC             AQU
# 2             MY              36.0       AOC             AQU
# 3             MY              36.0       AOC             PRX
# 4             MY              36.0       AOC             AQU
#
#    day_since_last_race  humidity  precipcover  precip  temp  maxt  cloudcover  \
# 0                 37.0     73.59        20.83     0.3  50.5  59.1        67.6
# 1                 25.0     73.59        20.83     0.3  50.5  59.1        67.6
# 2                 37.0     73.59        20.83     0.3  50.5  59.1        67.6
# 3                 17.0     73.59        20.83     0.3  50.5  59.1        67.6
# 4                 37.0     73.59        20.83     0.3  50.5  59.1        67.6
#
#                                weathertype  snow
# 0  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0
# 1  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0
# 2  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0
# 3  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0
# 4  Mist, Rain, Fog, Heavy Rain, Light Rain   0.0

# %%
# Separate the training data to numericals, categoricals and the text.
cat_col = []
num_col = []

for i in data.columns:
  if data[i].dtype == object:
    cat_col.append((i, data.columns.get_loc(i)))

  elif data[i].dtype == float:
    num_col.append((i, data.columns.get_loc(i)))

# %%
# Label encode the categorical variables and standarlize the numericals. 
for i in cat_col:
  le = preprocessing.LabelEncoder()
  data[i[0]] = le.fit_transform(data[i[0]])

num_col_name = [j[0] for j in num_col]
cat_col_name = [j[0] for j in cat_col]

se = preprocessing.StandardScaler()
data[num_col_name] = se.fit_transform(data[num_col_name])

se = preprocessing.StandardScaler()
target[['odds']] = se.fit_transform(target[['odds']])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
# Create a dict for the unique categories and the desired embedding dimensions for each categorical variable. 
# Jeremy Howard provides the following rule of thumb; embedding size = min(50, number of categories/2).
def create_embedding_dim():

  embedding_dim = {}
  for i in range(len(cat_col)):
    embedding_dim[cat_col[i][0]] = (data[cat_col[i][0]].nunique(), min(50, data[cat_col[i][0]].nunique() //2 ))

  return embedding_dim

# %%
embedding_dim = create_embedding_dim()

# %%
# Convert the comments column to tokes and pad each sequence.

max_words = 1133 # The length of the vocabulary.

# Make the units matrices.
tokenizer = Tokenizer(max_words)
tokenizer.fit_on_texts(df['Comments'])
data_text = tokenizer.texts_to_sequences(df['Comments'])

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# Maximum length for a vector.
maxlen = 15

# Pad the sequence.
data_text = pad_sequences(data_text, maxlen=maxlen)

print('Shape of data tensor:', data_text.shape)
# Out:
# Found 1133 unique tokens.
# Shape of data tensor: (15081, 15)

# %%
# Concat the regular features with text features. Transform them all to numpy array.
data = np.concatenate((np.asarray(data), data_text), axis=1)
target = np.asarray(target)

# %% [markdown]
# ## Modeling

# %% [markdown]
# Here I build the model mainly with a class and Keras functional API for it will allow us to build a more flexible model.

# %%
class NN():

    def __init__(self, cat_col, cat_col_name, embedding_dim):
      # For each categorical variable, we need to specify a input layer and a embedding layer. So I created them all by iteratively specifying them as attributes.
      for i in cat_col_name:

        # These are all the input layers for the cat_col
        setattr(self, i + '_input', keras.Input(shape=(1,), name=i))

        #Then we embed them by the dimensions we created earlier.
        setattr(self, i + '_embedding', layers.Embedding(embedding_dim[i][0], embedding_dim[i][1], input_length = 1)(getattr(self, i + '_input')))

        # Next we rehsape them so that they can be concatenated with other layers' output.
        setattr(self, i + '_reshape', layers.Reshape(target_shape=(embedding_dim[i][1], ))(getattr(self, i + '_embedding')))

      # Input for the numerical variables.
      setattr(self, 'num_input', keras.Input(shape=(len(num_col),), name = 'num_col'))
      setattr(self, 'num_features', layers.Dense(64, activation='relu')(getattr(self, 'num_input')))

      # Input and embedding layers for the texts variable.
      setattr(self, 'text_input', keras.Input(shape=(None,), name = 'text'))
      setattr(self, 'text_embedding', layers.Embedding(1000, 64)(getattr(self, 'text_input')))

    def concat(self):

      # LSTM layer for the text data.
      text_features = layers.LSTM(256, dropout = 0.05, recurrent_dropout=0.1)(getattr(self, 'text_embedding'))

      # Reshape the text output so that the outputs can be concatenated
      text_features = layers.Reshape(target_shape=(256, ))(text_features)

      # Concatenate all outputs from previous layers.
      x = layers.concatenate([getattr(self, i + '_reshape') for i in cat_col_name] + [getattr(self, 'num_features')] + [text_features])

      # More dense layers.
      x = layers.Dense(128, activation="relu", name="dense1", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dropout(0.2)(x)
      x = layers.Dense(256, activation="relu", name="dense2", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dropout(0.2)(x)
      x = layers.Dense(128, activation="relu", name="dense3", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dense(64, activation="relu", name="dense4", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      pred = layers.Dense(1,  name="prediction")(x)

      # Compiling the model by specifying the inputs and outputs.
      model = keras.Model(
      inputs=[getattr(self, i + '_input') for i in cat_col_name] + [getattr(self, 'num_input')] + [getattr(self, 'text_input')],
      outputs=[pred])

      return model

# %% [markdown]
# For different outcome variables, we can just change the layer that generate the prediction, the loss and the metric.

# %% [markdown]
# For hyperparameter tuning, I think apart from changing the regular ones, we can also all more layers. Maybe some dense layer after the categorical embedding layer.

# %%
from tensorflow.keras import optimizers

def build_model(cat_col, cat_col_name, embedding_dim):

  # Instantiate the model.
  model = NN(cat_col, cat_col_name, embedding_dim)
  model = model.concat()

  model.compile(
    optimizer=optimizers.Adam(learning_rate=0.01),
    loss={
        #"prediction": keras.losses.BinaryCrossentropy(from_logits=True)
        "prediction": keras.losses.mean_squared_error 
    },
    metrics=['mae']
    #metrics=['acc']
)
  return model

# %%
# Instantiate the model.
model = build_model(cat_col, cat_col_name, embedding_dim)
# Out:
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# Check the dimensions and the graph of layers.
model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "model_36"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text (InputLayer)              [(None, None)]       0           []
#
#  track_id (InputLayer)          [(None, 1)]          0           []
#
#  program_number (InputLayer)    [(None, 1)]          0           []
#
#  jockey (InputLayer)            [(None, 1)]          0           []
#
#  course_type (InputLayer)       [(None, 1)]          0           []
#
#  track_condition (InputLayer)   [(None, 1)]          0           []
#
#  race_type (InputLayer)         [(None, 1)]          0           []
#
#  last_race_track (InputLayer)   [(None, 1)]          0           []
#
#  weathertype (InputLayer)       [(None, 1)]          0           []
#
#  embedding_332 (Embedding)      (None, None, 64)     64000       ['text[0][0]']
#
#  embedding_324 (Embedding)      (None, 1, 1)         3           ['track_id[0][0]']
#
#  embedding_325 (Embedding)      (None, 1, 10)        200         ['program_number[0][0]']
#
#  embedding_326 (Embedding)      (None, 1, 50)        8900        ['jockey[0][0]']
#
#  embedding_327 (Embedding)      (None, 1, 2)         10          ['course_type[0][0]']
#
#  embedding_328 (Embedding)      (None, 1, 3)         21          ['track_condition[0][0]']
#
#  embedding_329 (Embedding)      (None, 1, 6)         72          ['race_type[0][0]']
#
#  embedding_330 (Embedding)      (None, 1, 50)        9150        ['last_race_track[0][0]']
#
#  embedding_331 (Embedding)      (None, 1, 25)        1275        ['weathertype[0][0]']
#
#  num_col (InputLayer)           [(None, 10)]         0           []
#
#  lstm_36 (LSTM)                 (None, 256)          328704      ['embedding_332[0][0]']
#
#  reshape_324 (Reshape)          (None, 1)            0           ['embedding_324[0][0]']
#
#  reshape_325 (Reshape)          (None, 10)           0           ['embedding_325[0][0]']
#
#  reshape_326 (Reshape)          (None, 50)           0           ['embedding_326[0][0]']
#
#  reshape_327 (Reshape)          (None, 2)            0           ['embedding_327[0][0]']
#
#  reshape_328 (Reshape)          (None, 3)            0           ['embedding_328[0][0]']
#
#  reshape_329 (Reshape)          (None, 6)            0           ['embedding_329[0][0]']
#
#  reshape_330 (Reshape)          (None, 50)           0           ['embedding_330[0][0]']
#
#  reshape_331 (Reshape)          (None, 25)           0           ['embedding_331[0][0]']
#
#  dense_36 (Dense)               (None, 64)           704         ['num_col[0][0]']
#
#  reshape_332 (Reshape)          (None, 256)          0           ['lstm_36[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 467)          0           ['reshape_324[0][0]',
#                                                                   'reshape_325[0][0]',
#                                                                   'reshape_326[0][0]',
#                                                                   'reshape_327[0][0]',
#                                                                   'reshape_328[0][0]',
#                                                                   'reshape_329[0][0]',
#                                                                   'reshape_330[0][0]',
#                                                                   'reshape_331[0][0]',
#                                                                   'dense_36[0][0]',
#                                                                   'reshape_332[0][0]']
#
#  dense1 (Dense)                 (None, 128)          59904       ['concatenate_36[0][0]']
#
#  dropout_44 (Dropout)           (None, 128)          0           ['dense1[0][0]']
#
#  dense2 (Dense)                 (None, 256)          33024       ['dropout_44[0][0]']
#
#  dropout_45 (Dropout)           (None, 256)          0           ['dense2[0][0]']
#
#  dense3 (Dense)                 (None, 128)          32896       ['dropout_45[0][0]']
#
#  dense4 (Dense)                 (None, 64)           8256        ['dense3[0][0]']
#
#  prediction (Dense)             (None, 1)            65          ['dense4[0][0]']
#
# ==================================================================================================
# Total params: 547,184
# Trainable params: 547,184
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# This function aims to turn the whole data numpy array to the form that the model can take.
def create_data(whole_data):

  output = {}
  for i in cat_col:
    output[i[0]] = whole_data[:,i[1]]
  output['num_col'] = whole_data[:,[j[1] for j in num_col]]
  output['text'] = whole_data[:, -15:]

  return output

# %%
# 4-fold cross validation and log the loss and metric.
# Split the data.
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=1)

# Specify the hyperparameters.
k=4
num_val_samples = len(x_train) // k 
num_epochs = 50
batch_size = 1000
all_train_histories = [] 
all_val_histories = []


for i in range(k):
    print('processing fold #', i + 1)
    
    # Create the validation data and recreate the training data.
    val_data_temp = x_train[i * num_val_samples: (i + 1) * num_val_samples] 
    val_targets_temp = y_train[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate( [x_train[:i * num_val_samples],
        x_train[(i + 1) * num_val_samples:]], axis=0)
    partial_train_targets = np.concatenate( [y_train[:i * num_val_samples],
        y_train[(i + 1) * num_val_samples:]], axis=0)

    #Create the model and train.
    model = build_model(cat_col, cat_col_name, embedding_dim)

    # Create the model usable data inputs.
    train_data = create_data(partial_train_data)
    val_data = create_data(val_data_temp)

    # Train the model.
    history = model.fit(
    train_data,
    {"prediction": partial_train_targets[:, -1]},
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data=(val_data, val_targets_temp[:, -1])
)
    
    # Log the loss
    train_history = history.history['loss']
    val_history = history.history['val_loss']
    all_train_histories.append(train_history)
    all_val_histories.append(val_history)
# Out:
# processing fold # 1
# WARNING:tensorflow:Layer lstm_42 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 10/10 [==============================] - 5s 145ms/step - loss: 1.0433 - mae: 0.6992 - val_loss: 1.0220 - val_mae: 0.6612
# Epoch 2/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.8820 - mae: 0.6161 - val_loss: 0.7718 - val_mae: 0.5382
# Epoch 3/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.6600 - mae: 0.5160 - val_loss: 0.7419 - val_mae: 0.4914
# Epoch 4/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.6669 - mae: 0.5361 - val_loss: 0.6845 - val_mae: 0.4939
# Epoch 5/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.5429 - mae: 0.4680 - val_loss: 0.7638 - val_mae: 0.5609
# Epoch 6/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.5403 - mae: 0.4661 - val_loss: 0.6671 - val_mae: 0.4960
# Epoch 7/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.4837 - mae: 0.4429 - val_loss: 0.7291 - val_mae: 0.5536
# Epoch 8/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.4873 - mae: 0.4578 - val_loss: 0.7947 - val_mae: 0.5535
# Epoch 9/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.4803 - mae: 0.4430 - val_loss: 0.6970 - val_mae: 0.5020
# Epoch 10/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.4416 - mae: 0.4270 - val_loss: 0.7557 - val_mae: 0.5464
# Epoch 11/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4379 - mae: 0.4299 - val_loss: 0.6789 - val_mae: 0.4849
# Epoch 12/50
# 10/10 [==============================] - 1s 95ms/step - loss: 0.4280 - mae: 0.4193 - val_loss: 0.7219 - val_mae: 0.5348
# Epoch 13/50
# 10/10 [==============================] - 1s 94ms/step - loss: 0.3939 - mae: 0.4189 - val_loss: 0.7212 - val_mae: 0.5180
# Epoch 14/50
# 10/10 [==============================] - 1s 95ms/step - loss: 0.3836 - mae: 0.4013 - val_loss: 0.6851 - val_mae: 0.5181
# Epoch 15/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3986 - mae: 0.4111 - val_loss: 0.7639 - val_mae: 0.5421
# Epoch 16/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3682 - mae: 0.3970 - val_loss: 0.7319 - val_mae: 0.5351
# Epoch 17/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.3502 - mae: 0.3856 - val_loss: 0.7527 - val_mae: 0.5177
# Epoch 18/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3596 - mae: 0.3869 - val_loss: 0.7117 - val_mae: 0.5109
# Epoch 19/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.3759 - mae: 0.3933 - val_loss: 0.8055 - val_mae: 0.5309
# Epoch 20/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3614 - mae: 0.3816 - val_loss: 0.7060 - val_mae: 0.5014
# Epoch 21/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.3524 - mae: 0.3779 - val_loss: 0.8569 - val_mae: 0.5607
# Epoch 22/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.3370 - mae: 0.3805 - val_loss: 0.8368 - val_mae: 0.5467
# Epoch 23/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.3236 - mae: 0.3745 - val_loss: 0.7637 - val_mae: 0.5092
# Epoch 24/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3228 - mae: 0.3658 - val_loss: 0.9756 - val_mae: 0.5612
# Epoch 25/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3611 - mae: 0.3782 - val_loss: 0.8146 - val_mae: 0.5227
# Epoch 26/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3089 - mae: 0.3604 - val_loss: 0.7611 - val_mae: 0.5024
# Epoch 27/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3265 - mae: 0.3658 - val_loss: 0.7758 - val_mae: 0.5203
# Epoch 28/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.3149 - mae: 0.3633 - val_loss: 0.8799 - val_mae: 0.5362
# Epoch 29/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3140 - mae: 0.3617 - val_loss: 0.7548 - val_mae: 0.5077
# Epoch 30/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2936 - mae: 0.3475 - val_loss: 0.7858 - val_mae: 0.5138
# Epoch 31/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.2814 - mae: 0.3424 - val_loss: 0.7566 - val_mae: 0.5044
# Epoch 32/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.3133 - mae: 0.3520 - val_loss: 0.8019 - val_mae: 0.5355
# Epoch 33/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3031 - mae: 0.3535 - val_loss: 0.8017 - val_mae: 0.5207
# Epoch 34/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.2938 - mae: 0.3489 - val_loss: 0.9326 - val_mae: 0.5539
# Epoch 35/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3114 - mae: 0.3542 - val_loss: 0.8732 - val_mae: 0.5379
# Epoch 36/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2747 - mae: 0.3376 - val_loss: 0.8978 - val_mae: 0.5564
# Epoch 37/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2996 - mae: 0.3489 - val_loss: 0.7924 - val_mae: 0.5292
# Epoch 38/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2917 - mae: 0.3444 - val_loss: 0.7567 - val_mae: 0.5242
# Epoch 39/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2789 - mae: 0.3414 - val_loss: 0.8515 - val_mae: 0.5339
# Epoch 40/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.2640 - mae: 0.3286 - val_loss: 0.7684 - val_mae: 0.5302
# Epoch 41/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2608 - mae: 0.3333 - val_loss: 0.8108 - val_mae: 0.5151
# Epoch 42/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2687 - mae: 0.3327 - val_loss: 0.8399 - val_mae: 0.5517
# Epoch 43/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.2419 - mae: 0.3257 - val_loss: 0.9518 - val_mae: 0.5943
# Epoch 44/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2809 - mae: 0.3452 - val_loss: 0.9193 - val_mae: 0.5622
# Epoch 45/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.2658 - mae: 0.3347 - val_loss: 0.7452 - val_mae: 0.5046
# Epoch 46/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.4000 - mae: 0.3782 - val_loss: 0.7947 - val_mae: 0.5115
# Epoch 47/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2960 - mae: 0.3474 - val_loss: 0.9905 - val_mae: 0.5722
# Epoch 48/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.3089 - mae: 0.3457 - val_loss: 0.8726 - val_mae: 0.5410
# Epoch 49/50
# 10/10 [==============================] - 1s 94ms/step - loss: 0.2597 - mae: 0.3261 - val_loss: 0.8670 - val_mae: 0.5504
# Epoch 50/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2353 - mae: 0.3139 - val_loss: 0.9092 - val_mae: 0.5479
# WARNING:tensorflow:Layer lstm_43 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# processing fold # 2
# Epoch 1/50
# 10/10 [==============================] - 42s 4s/step - loss: 1.3729 - mae: 0.7974 - val_loss: 0.8640 - val_mae: 0.5896
# Epoch 2/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.9968 - mae: 0.5821 - val_loss: 0.8185 - val_mae: 0.5460
# Epoch 3/50
# 10/10 [==============================] - 1s 123ms/step - loss: 0.9550 - mae: 0.5507 - val_loss: 0.8050 - val_mae: 0.5599
# Epoch 4/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.9281 - mae: 0.5498 - val_loss: 0.7645 - val_mae: 0.5034
# Epoch 5/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.8916 - mae: 0.5305 - val_loss: 0.7451 - val_mae: 0.4980
# Epoch 6/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.8649 - mae: 0.5246 - val_loss: 0.7291 - val_mae: 0.4965
# Epoch 7/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.8383 - mae: 0.5202 - val_loss: 0.7142 - val_mae: 0.5175
# Epoch 8/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.8128 - mae: 0.5124 - val_loss: 0.7343 - val_mae: 0.5072
# Epoch 9/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.8048 - mae: 0.5241 - val_loss: 0.6854 - val_mae: 0.4892
# Epoch 10/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.7687 - mae: 0.4996 - val_loss: 0.6590 - val_mae: 0.5115
# Epoch 11/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.6468 - mae: 0.4870 - val_loss: 0.5855 - val_mae: 0.4682
# Epoch 12/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.5935 - mae: 0.4735 - val_loss: 0.5674 - val_mae: 0.4647
# Epoch 13/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.5487 - mae: 0.4596 - val_loss: 0.5864 - val_mae: 0.4892
# Epoch 14/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.5166 - mae: 0.4493 - val_loss: 0.5580 - val_mae: 0.4727
# Epoch 15/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4817 - mae: 0.4332 - val_loss: 0.6436 - val_mae: 0.5034
# Epoch 16/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.5026 - mae: 0.4380 - val_loss: 0.5983 - val_mae: 0.4849
# Epoch 17/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.4899 - mae: 0.4443 - val_loss: 0.5893 - val_mae: 0.4574
# Epoch 18/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.4635 - mae: 0.4245 - val_loss: 0.5907 - val_mae: 0.5021
# Epoch 19/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.4306 - mae: 0.4104 - val_loss: 0.6004 - val_mae: 0.4943
# Epoch 20/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.4093 - mae: 0.4040 - val_loss: 0.5912 - val_mae: 0.4667
# Epoch 21/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.4196 - mae: 0.4058 - val_loss: 0.5906 - val_mae: 0.4712
# Epoch 22/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.4063 - mae: 0.3948 - val_loss: 0.6010 - val_mae: 0.4926
# Epoch 23/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.3868 - mae: 0.3912 - val_loss: 0.5993 - val_mae: 0.4849
# Epoch 24/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3736 - mae: 0.3839 - val_loss: 0.5992 - val_mae: 0.4823
# Epoch 25/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.3815 - mae: 0.4022 - val_loss: 0.6489 - val_mae: 0.5071
# Epoch 26/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3736 - mae: 0.3931 - val_loss: 0.6296 - val_mae: 0.4772
# Epoch 27/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3709 - mae: 0.3839 - val_loss: 0.6354 - val_mae: 0.4702
# Epoch 28/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3558 - mae: 0.3721 - val_loss: 0.6966 - val_mae: 0.5180
# Epoch 29/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3746 - mae: 0.3875 - val_loss: 0.8152 - val_mae: 0.5511
# Epoch 30/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3929 - mae: 0.3905 - val_loss: 0.8107 - val_mae: 0.5602
# Epoch 31/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.3996 - mae: 0.3930 - val_loss: 0.6908 - val_mae: 0.5174
# Epoch 32/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.3726 - mae: 0.3850 - val_loss: 0.6356 - val_mae: 0.4920
# Epoch 33/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3269 - mae: 0.3618 - val_loss: 0.6361 - val_mae: 0.4914
# Epoch 34/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3030 - mae: 0.3504 - val_loss: 0.6910 - val_mae: 0.4921
# Epoch 35/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2972 - mae: 0.3446 - val_loss: 0.7043 - val_mae: 0.5019
# Epoch 36/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2926 - mae: 0.3438 - val_loss: 0.6723 - val_mae: 0.4976
# Epoch 37/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.2797 - mae: 0.3328 - val_loss: 0.6780 - val_mae: 0.4850
# Epoch 38/50
# 10/10 [==============================] - 1s 149ms/step - loss: 0.2747 - mae: 0.3325 - val_loss: 0.6414 - val_mae: 0.4807
# Epoch 39/50
# 10/10 [==============================] - 2s 176ms/step - loss: 0.2893 - mae: 0.3398 - val_loss: 0.6543 - val_mae: 0.4887
# Epoch 40/50
# 10/10 [==============================] - 1s 118ms/step - loss: 0.2776 - mae: 0.3341 - val_loss: 0.6733 - val_mae: 0.5020
# Epoch 41/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2751 - mae: 0.3378 - val_loss: 0.6978 - val_mae: 0.5205
# Epoch 42/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.2537 - mae: 0.3286 - val_loss: 0.6605 - val_mae: 0.5099
# Epoch 43/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2497 - mae: 0.3227 - val_loss: 0.6728 - val_mae: 0.4900
# Epoch 44/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2522 - mae: 0.3265 - val_loss: 0.6500 - val_mae: 0.4973
# Epoch 45/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2430 - mae: 0.3187 - val_loss: 0.7321 - val_mae: 0.4940
# Epoch 46/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2563 - mae: 0.3171 - val_loss: 0.7047 - val_mae: 0.5116
# Epoch 47/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2354 - mae: 0.3087 - val_loss: 0.7479 - val_mae: 0.5190
# Epoch 48/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2614 - mae: 0.3256 - val_loss: 0.7253 - val_mae: 0.5251
# Epoch 49/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2345 - mae: 0.3101 - val_loss: 0.6423 - val_mae: 0.4857
# Epoch 50/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.2300 - mae: 0.3069 - val_loss: 0.6726 - val_mae: 0.4829
# WARNING:tensorflow:Layer lstm_44 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# processing fold # 3
# Epoch 1/50
# 10/10 [==============================] - 5s 142ms/step - loss: 1.0557 - mae: 0.6980 - val_loss: 1.0121 - val_mae: 0.6436
# Epoch 2/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.9104 - mae: 0.5745 - val_loss: 0.8081 - val_mae: 0.5264
# Epoch 3/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.6865 - mae: 0.5223 - val_loss: 0.7324 - val_mae: 0.5119
# Epoch 4/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.6761 - mae: 0.5353 - val_loss: 0.7710 - val_mae: 0.5243
# Epoch 5/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.6228 - mae: 0.5148 - val_loss: 0.6859 - val_mae: 0.5587
# Epoch 6/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.5534 - mae: 0.4875 - val_loss: 0.6670 - val_mae: 0.5224
# Epoch 7/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.5205 - mae: 0.4565 - val_loss: 0.6756 - val_mae: 0.5156
# Epoch 8/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.5181 - mae: 0.4621 - val_loss: 0.6699 - val_mae: 0.5008
# Epoch 9/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4894 - mae: 0.4403 - val_loss: 0.6774 - val_mae: 0.5147
# Epoch 10/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4715 - mae: 0.4340 - val_loss: 0.8043 - val_mae: 0.5853
# Epoch 11/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4834 - mae: 0.4479 - val_loss: 0.6809 - val_mae: 0.5033
# Epoch 12/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.4633 - mae: 0.4309 - val_loss: 0.6877 - val_mae: 0.4986
# Epoch 13/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4472 - mae: 0.4254 - val_loss: 0.6959 - val_mae: 0.4939
# Epoch 14/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4955 - mae: 0.4464 - val_loss: 0.7400 - val_mae: 0.5346
# Epoch 15/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.4384 - mae: 0.4242 - val_loss: 0.7031 - val_mae: 0.5513
# Epoch 16/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4402 - mae: 0.4312 - val_loss: 0.6861 - val_mae: 0.5219
# Epoch 17/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4414 - mae: 0.4271 - val_loss: 0.6876 - val_mae: 0.5003
# Epoch 18/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4151 - mae: 0.4114 - val_loss: 0.6820 - val_mae: 0.5087
# Epoch 19/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.3789 - mae: 0.3924 - val_loss: 0.7301 - val_mae: 0.5275
# Epoch 20/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.3511 - mae: 0.3813 - val_loss: 0.7534 - val_mae: 0.5239
# Epoch 21/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3427 - mae: 0.3740 - val_loss: 0.7691 - val_mae: 0.5436
# Epoch 22/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3441 - mae: 0.3877 - val_loss: 0.7848 - val_mae: 0.5533
# Epoch 23/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.3324 - mae: 0.3731 - val_loss: 0.7199 - val_mae: 0.5284
# Epoch 24/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.3222 - mae: 0.3692 - val_loss: 0.9271 - val_mae: 0.5733
# Epoch 25/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.3427 - mae: 0.3736 - val_loss: 0.7236 - val_mae: 0.5095
# Epoch 26/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3795 - mae: 0.3851 - val_loss: 0.8191 - val_mae: 0.5245
# Epoch 27/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3479 - mae: 0.3808 - val_loss: 0.7590 - val_mae: 0.5261
# Epoch 28/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3233 - mae: 0.3655 - val_loss: 0.8284 - val_mae: 0.5429
# Epoch 29/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.3086 - mae: 0.3598 - val_loss: 0.8953 - val_mae: 0.5590
# Epoch 30/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.3126 - mae: 0.3625 - val_loss: 0.7908 - val_mae: 0.5290
# Epoch 31/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2963 - mae: 0.3536 - val_loss: 0.7609 - val_mae: 0.5053
# Epoch 32/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.2715 - mae: 0.3395 - val_loss: 0.8246 - val_mae: 0.5323
# Epoch 33/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2656 - mae: 0.3323 - val_loss: 0.8539 - val_mae: 0.5427
# Epoch 34/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.2504 - mae: 0.3238 - val_loss: 0.8182 - val_mae: 0.5354
# Epoch 35/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.2547 - mae: 0.3239 - val_loss: 0.8457 - val_mae: 0.5621
# Epoch 36/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2769 - mae: 0.3410 - val_loss: 0.8006 - val_mae: 0.5311
# Epoch 37/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2672 - mae: 0.3336 - val_loss: 0.7927 - val_mae: 0.5306
# Epoch 38/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2515 - mae: 0.3239 - val_loss: 0.7654 - val_mae: 0.5160
# Epoch 39/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.3180 - mae: 0.3534 - val_loss: 0.8800 - val_mae: 0.5438
# Epoch 40/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3135 - mae: 0.3572 - val_loss: 0.7959 - val_mae: 0.5322
# Epoch 41/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.2859 - mae: 0.3430 - val_loss: 0.7574 - val_mae: 0.5105
# Epoch 42/50
# 10/10 [==============================] - 1s 95ms/step - loss: 0.2920 - mae: 0.3452 - val_loss: 0.8055 - val_mae: 0.5249
# Epoch 43/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2670 - mae: 0.3298 - val_loss: 0.9332 - val_mae: 0.5752
# Epoch 44/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2797 - mae: 0.3354 - val_loss: 0.8266 - val_mae: 0.5424
# Epoch 45/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2417 - mae: 0.3139 - val_loss: 0.8554 - val_mae: 0.5426
# Epoch 46/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2506 - mae: 0.3162 - val_loss: 0.8480 - val_mae: 0.5391
# Epoch 47/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2394 - mae: 0.3139 - val_loss: 0.8326 - val_mae: 0.5372
# Epoch 48/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2111 - mae: 0.2993 - val_loss: 0.8171 - val_mae: 0.5364
# Epoch 49/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2065 - mae: 0.2916 - val_loss: 0.8231 - val_mae: 0.5484
# Epoch 50/50
# 10/10 [==============================] - 1s 95ms/step - loss: 0.2008 - mae: 0.2929 - val_loss: 0.8165 - val_mae: 0.5234
# WARNING:tensorflow:Layer lstm_45 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# processing fold # 4
# Epoch 1/50
# 10/10 [==============================] - 5s 141ms/step - loss: 1.8116 - mae: 0.8726 - val_loss: 1.0661 - val_mae: 0.6696
# Epoch 2/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.9820 - mae: 0.6435 - val_loss: 1.0045 - val_mae: 0.6190
# Epoch 3/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.8332 - mae: 0.5627 - val_loss: 0.7659 - val_mae: 0.5416
# Epoch 4/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.7002 - mae: 0.5349 - val_loss: 0.7043 - val_mae: 0.5389
# Epoch 5/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.6348 - mae: 0.5156 - val_loss: 0.7102 - val_mae: 0.5281
# Epoch 6/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.5904 - mae: 0.4888 - val_loss: 0.6853 - val_mae: 0.5103
# Epoch 7/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.5446 - mae: 0.4742 - val_loss: 0.7080 - val_mae: 0.5294
# Epoch 8/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.5318 - mae: 0.4677 - val_loss: 0.6985 - val_mae: 0.4961
# Epoch 9/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4969 - mae: 0.4536 - val_loss: 0.7634 - val_mae: 0.5335
# Epoch 10/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.5249 - mae: 0.4661 - val_loss: 0.7195 - val_mae: 0.5283
# Epoch 11/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4938 - mae: 0.4562 - val_loss: 0.7042 - val_mae: 0.5412
# Epoch 12/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.4610 - mae: 0.4348 - val_loss: 0.6956 - val_mae: 0.4990
# Epoch 13/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.4368 - mae: 0.4279 - val_loss: 0.7472 - val_mae: 0.5134
# Epoch 14/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4252 - mae: 0.4176 - val_loss: 0.7229 - val_mae: 0.5127
# Epoch 15/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.4063 - mae: 0.4117 - val_loss: 0.7816 - val_mae: 0.5245
# Epoch 16/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.4193 - mae: 0.4177 - val_loss: 0.8041 - val_mae: 0.5285
# Epoch 17/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.4212 - mae: 0.4186 - val_loss: 0.7000 - val_mae: 0.4928
# Epoch 18/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.4012 - mae: 0.4064 - val_loss: 0.7117 - val_mae: 0.4919
# Epoch 19/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.3972 - mae: 0.4045 - val_loss: 0.7805 - val_mae: 0.5225
# Epoch 20/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.3854 - mae: 0.4087 - val_loss: 0.7049 - val_mae: 0.5132
# Epoch 21/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.3802 - mae: 0.4007 - val_loss: 0.7117 - val_mae: 0.5045
# Epoch 22/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.3678 - mae: 0.3907 - val_loss: 0.7328 - val_mae: 0.5128
# Epoch 23/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.3500 - mae: 0.3844 - val_loss: 0.7236 - val_mae: 0.5019
# Epoch 24/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.3459 - mae: 0.3781 - val_loss: 0.7216 - val_mae: 0.5135
# Epoch 25/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3506 - mae: 0.3839 - val_loss: 0.7461 - val_mae: 0.5043
# Epoch 26/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3400 - mae: 0.3761 - val_loss: 0.6968 - val_mae: 0.4893
# Epoch 27/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.3356 - mae: 0.3734 - val_loss: 0.7123 - val_mae: 0.4940
# Epoch 28/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.3280 - mae: 0.3699 - val_loss: 0.8431 - val_mae: 0.5520
# Epoch 29/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3951 - mae: 0.4031 - val_loss: 0.8315 - val_mae: 0.5658
# Epoch 30/50
# 10/10 [==============================] - 1s 90ms/step - loss: 0.3950 - mae: 0.4047 - val_loss: 0.7246 - val_mae: 0.5343
# Epoch 31/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.3281 - mae: 0.3772 - val_loss: 0.7920 - val_mae: 0.5617
# Epoch 32/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.3761 - mae: 0.3918 - val_loss: 0.7461 - val_mae: 0.5492
# Epoch 33/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.3379 - mae: 0.3765 - val_loss: 0.7391 - val_mae: 0.5370
# Epoch 34/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3220 - mae: 0.3721 - val_loss: 0.7293 - val_mae: 0.5329
# Epoch 35/50
# 10/10 [==============================] - 1s 92ms/step - loss: 0.3033 - mae: 0.3579 - val_loss: 0.7070 - val_mae: 0.5114
# Epoch 36/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2855 - mae: 0.3501 - val_loss: 0.7374 - val_mae: 0.5282
# Epoch 37/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2786 - mae: 0.3574 - val_loss: 0.7355 - val_mae: 0.5111
# Epoch 38/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2772 - mae: 0.3449 - val_loss: 0.7367 - val_mae: 0.5110
# Epoch 39/50
# 10/10 [==============================] - 1s 93ms/step - loss: 0.2892 - mae: 0.3503 - val_loss: 0.7420 - val_mae: 0.5298
# Epoch 40/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.3012 - mae: 0.3539 - val_loss: 0.7440 - val_mae: 0.5341
# Epoch 41/50
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2872 - mae: 0.3518 - val_loss: 0.7502 - val_mae: 0.5352
# Epoch 42/50
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2736 - mae: 0.3468 - val_loss: 0.7365 - val_mae: 0.5075
# Epoch 43/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2572 - mae: 0.3359 - val_loss: 0.7694 - val_mae: 0.5189
# Epoch 44/50
# 10/10 [==============================] - 1s 86ms/step - loss: 0.2400 - mae: 0.3228 - val_loss: 0.7552 - val_mae: 0.5181
# Epoch 45/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.2382 - mae: 0.3213 - val_loss: 0.7366 - val_mae: 0.4885
# Epoch 46/50
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3329 - mae: 0.3619 - val_loss: 0.7981 - val_mae: 0.5234
# Epoch 47/50
# 10/10 [==============================] - 1s 139ms/step - loss: 0.2931 - mae: 0.3529 - val_loss: 0.7715 - val_mae: 0.5153
# Epoch 48/50
# 10/10 [==============================] - 2s 158ms/step - loss: 0.2870 - mae: 0.3499 - val_loss: 0.7968 - val_mae: 0.5239
# Epoch 49/50
# 10/10 [==============================] - 1s 133ms/step - loss: 0.2515 - mae: 0.3283 - val_loss: 0.7480 - val_mae: 0.5179
# Epoch 50/50
# 10/10 [==============================] - 1s 91ms/step - loss: 0.2364 - mae: 0.3172 - val_loss: 0.7471 - val_mae: 0.5090

# %%
# Calculate the average accuracy acorss validations.
average_train_history = [
    np.mean([x[i] for x in  all_train_histories]) for i in range(num_epochs)]

average_val_history = [
    np.mean([x[i] for x in all_val_histories]) for i in range(num_epochs)]

# %%
# Define a function to smooth the history of loss.
def smooth_curve(points, factor=0.9):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)
  return smoothed_points

# %%
#smooth_history1 = smooth_curve(average_train_history[10:])
smooth_history1 = smooth_curve(average_train_history)
smooth_history2 = smooth_curve(average_val_history)

# Plot the smmoothed history.
plt.plot(range(1, len(smooth_history1) + 1), smooth_history1, label = 'training')
plt.plot(range(1, len(smooth_history2) + 1), smooth_history2, label = 'validation')
plt.title('Predicting Odds with NN')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.savefig('NN_loss_odds.png')
plt.show()

# %%
train_data = create_data(x_train)
test_data = create_data(x_test)

# Train the final model.
model = build_model(cat_col, cat_col_name, embedding_dim)
model.fit(
    train_data,
    {"prediction": y_train[:, -1]},
    epochs=50,
    batch_size=1000)

# Print out the final results.
print(model.evaluate(train_data, y_train[:, -1]))
print(model.evaluate(test_data, y_test[:, -1]))
# Out:
# WARNING:tensorflow:Layer lstm_46 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 13/13 [==============================] - 5s 90ms/step - loss: 1.1109 - mae: 0.7323
# Epoch 2/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.9488 - mae: 0.5516
# Epoch 3/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.7289 - mae: 0.5434
# Epoch 4/50
# 13/13 [==============================] - 1s 85ms/step - loss: 0.6306 - mae: 0.5035
# Epoch 5/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.5796 - mae: 0.4870
# Epoch 6/50
# 13/13 [==============================] - 1s 79ms/step - loss: 0.5466 - mae: 0.4657
# Epoch 7/50
# 13/13 [==============================] - 1s 78ms/step - loss: 0.5168 - mae: 0.4536
# Epoch 8/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.5067 - mae: 0.4502
# Epoch 9/50
# 13/13 [==============================] - 1s 78ms/step - loss: 0.5049 - mae: 0.4507
# Epoch 10/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.4548 - mae: 0.4347
# Epoch 11/50
# 13/13 [==============================] - 1s 79ms/step - loss: 0.4407 - mae: 0.4284
# Epoch 12/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.4502 - mae: 0.4263
# Epoch 13/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.4118 - mae: 0.4127
# Epoch 14/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.3973 - mae: 0.4074
# Epoch 15/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.3941 - mae: 0.4079
# Epoch 16/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.3882 - mae: 0.3998
# Epoch 17/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.3795 - mae: 0.3974
# Epoch 18/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.3651 - mae: 0.3917
# Epoch 19/50
# 13/13 [==============================] - 1s 86ms/step - loss: 0.3732 - mae: 0.3899
# Epoch 20/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.3595 - mae: 0.3848
# Epoch 21/50
# 13/13 [==============================] - 1s 84ms/step - loss: 0.3507 - mae: 0.3806
# Epoch 22/50
# 13/13 [==============================] - 1s 79ms/step - loss: 0.3679 - mae: 0.3907
# Epoch 23/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.3369 - mae: 0.3843
# Epoch 24/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.3298 - mae: 0.3711
# Epoch 25/50
# 13/13 [==============================] - 1s 78ms/step - loss: 0.3162 - mae: 0.3668
# Epoch 26/50
# 13/13 [==============================] - 1s 78ms/step - loss: 0.3621 - mae: 0.3874
# Epoch 27/50
# 13/13 [==============================] - 1s 79ms/step - loss: 0.3354 - mae: 0.3772
# Epoch 28/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.3295 - mae: 0.3725
# Epoch 29/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.3022 - mae: 0.3534
# Epoch 30/50
# 13/13 [==============================] - 1s 83ms/step - loss: 0.2747 - mae: 0.3432
# Epoch 31/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.2712 - mae: 0.3397
# Epoch 32/50
# 13/13 [==============================] - 1s 84ms/step - loss: 0.2520 - mae: 0.3291
# Epoch 33/50
# 13/13 [==============================] - 1s 83ms/step - loss: 0.2483 - mae: 0.3246
# Epoch 34/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.2397 - mae: 0.3210
# Epoch 35/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.2302 - mae: 0.3131
# Epoch 36/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.2725 - mae: 0.3298
# Epoch 37/50
# 13/13 [==============================] - 1s 85ms/step - loss: 0.2577 - mae: 0.3279
# Epoch 38/50
# 13/13 [==============================] - 1s 84ms/step - loss: 0.2349 - mae: 0.3138
# Epoch 39/50
# 13/13 [==============================] - 1s 84ms/step - loss: 0.2208 - mae: 0.3030
# Epoch 40/50
# 13/13 [==============================] - 1s 77ms/step - loss: 0.2159 - mae: 0.3043
# Epoch 41/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.2160 - mae: 0.3035
# Epoch 42/50
# 13/13 [==============================] - 1s 79ms/step - loss: 0.2147 - mae: 0.3014
# Epoch 43/50
# 13/13 [==============================] - 1s 84ms/step - loss: 0.2085 - mae: 0.2971
# Epoch 44/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.1956 - mae: 0.2879
# Epoch 45/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.2053 - mae: 0.2925
# Epoch 46/50
# 13/13 [==============================] - 1s 85ms/step - loss: 0.2068 - mae: 0.2933
# Epoch 47/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.1947 - mae: 0.2861
# Epoch 48/50
# 13/13 [==============================] - 1s 79ms/step - loss: 0.1908 - mae: 0.2806
# Epoch 49/50
# 13/13 [==============================] - 1s 79ms/step - loss: 0.1856 - mae: 0.2760
# Epoch 50/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.1905 - mae: 0.2826
# 377/377 [==============================] - 4s 8ms/step - loss: 0.1616 - mae: 0.2535
# [0.16158601641654968, 0.25354933738708496]
# 95/95 [==============================] - 1s 8ms/step - loss: 0.7668 - mae: 0.5065
# [0.7668454051017761, 0.50645911693573]
