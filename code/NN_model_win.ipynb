# %%
# !pip install wordninja
# !pip install num2words

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import regularizers
from sklearn import preprocessing
import wordninja
from nltk.tokenize import RegexpTokenizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import re
import num2words
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

pd.set_option('display.max_columns', None)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordninja in /usr/local/lib/python3.8/dist-packages (2.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: num2words in /usr/local/lib/python3.8/dist-packages (0.5.12)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.8/dist-packages (from num2words) (0.6.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Specify the path to our shared drive. Should work for all of us.
path = '/content/drive/Shareddrives/ANLY590_GROUP_4_PROJECT'

# %%
df = pd.read_csv(path + "/data/merged_data/joined_data_without_position.csv", index_col=0)

# %% [markdown]
# ## Preprocessing

# %%
# Create win dummy variable.
df['win'] = np.where(df['race_number'] >= 3, 1, 0)

# Drop the redundant variables.
df = df.drop(['position_at_finish', 'post_time', 'distance_id'], axis = 1)

# Convert the race number as string.
df['race_number'] = df['race_number'].astype('str')

# Convert to float and fill NA
df['day_since_last_race'] = df['day_since_last_race'].apply(lambda x : x[:-5] if x is not np.nan else np.nan).astype('float').fillna(0)

# Fill the comments column with string None.
df['Comments'] = df['Comments'].fillna('None')

# %%
# Preprocess the comments. 
res = []
tokenizer = RegexpTokenizer(r'\w+')
for i in df.Comments:
  if type(i) == str:
    re.sub(r"(\d+)", lambda x: num2words.num2words(int(x.group(0))), i)
    phrase_list = tokenizer.tokenize(i)
    splited_tokens = [wordninja.split(i) for i in phrase_list]
    flat_splited_tokens = [j for sublist in splited_tokens for j in sublist]
    res.append(flat_splited_tokens)    
  else:
    res.append(np.nan)

df['Comments'] = res

# %%
# Convert all numerical columns to float.
for i in df.columns:
  if df[i].dtype == int:
    df[i] = df[i].astype('float')

# %% [markdown]
# Here I concat all three outcome variables, so when training, be mindful about the column index

# %%
df.columns
# Out:
# Index(['track_id', 'race_date', 'race_number', 'program_number',
#        'weight_carried', 'jockey', 'odds', 'course_type', 'track_condition',
#        'run_up_distance', 'race_type', 'purse', 'last_race_track',
#        'day_since_last_race', 'Comments', 'seconds_in_race', 'humidity',
#        'precipcover', 'precip', 'temp', 'maxt', 'cloudcover', 'weathertype',
#        'snow', 'win'],
#       dtype='object')

# %%
# Separate the target data and others.
# dropping some extra variables to fix info leakage
target = df[['win']]
data = df.drop(['win', 'odds', 'purse','Comments', "seconds_in_race", "race_number", "race_date"], axis = 1)

# %%
data.shape
# Out:
# (15081, 18)

# %%
# Separate the training data to numericals, categoricals and the text.
cat_col = []
num_col = []

for i in data.columns:
  if data[i].dtype == object:
    cat_col.append((i, data.columns.get_loc(i)))

  elif data[i].dtype == float:
    num_col.append((i, data.columns.get_loc(i)))

# %%
# Label encode the categorical variables and standarlize the numericals. 
for i in cat_col:
  le = preprocessing.LabelEncoder()
  data[i[0]] = le.fit_transform(data[i[0]])

num_col_name = [j[0] for j in num_col]
cat_col_name = [j[0] for j in cat_col]

se = preprocessing.StandardScaler()
data[num_col_name] = se.fit_transform(data[num_col_name])

se = preprocessing.StandardScaler()
#target[['odds', 'purse']] = se.fit_transform(target[['odds', 'purse']])

# %%
# Create a dict for the unique categories and the desired embedding dimensions for each categorical variable. 
# Jeremy Howard provides the following rule of thumb; embedding size = min(50, number of categories/2).
def create_embedding_dim():

  embedding_dim = {}
  for i in range(len(cat_col)):
    embedding_dim[cat_col[i][0]] = (data[cat_col[i][0]].nunique(), min(50, data[cat_col[i][0]].nunique() //2 ))

  return embedding_dim

# %%
embedding_dim = create_embedding_dim()

# %%
# Convert the comments column to tokes and pad each sequence.

max_words = 1133 # The length of the vocabulary.

# Make the units matrices.
tokenizer = Tokenizer(max_words)
tokenizer.fit_on_texts(df['Comments'])
data_text = tokenizer.texts_to_sequences(df['Comments'])

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# Maximum length for a vector.
maxlen = 15

# Pad the sequence.
data_text = pad_sequences(data_text, maxlen=maxlen)

print('Shape of data tensor:', data_text.shape)
# Out:
# Found 1133 unique tokens.
# Shape of data tensor: (15081, 15)

# %%
# Concat the regular features with text features. Transform them all to numpy array.
data = np.concatenate((np.asarray(data), data_text), axis=1)
target = np.asarray(target)

# %% [markdown]
# ## Modeling

# %% [markdown]
# Here I build the model mainly with a class and Keras functional API for it will allow us to build a more flexible model.

# %%
class NN():

    def __init__(self, cat_col, cat_col_name, embedding_dim):
      # For each categorical variable, we need to specify a input layer and a embedding layer. So I created them all by iteratively specifying them as attributes.
      for i in cat_col_name:

        # These are all the input layers for the cat_col
        setattr(self, i + '_input', keras.Input(shape=(1,), name=i))

        #Then we embed them by the dimensions we created earlier.
        setattr(self, i + '_embedding', layers.Embedding(embedding_dim[i][0], embedding_dim[i][1], input_length = 1)(getattr(self, i + '_input')))

        # Next we rehsape them so that they can be concatenated with other layers' output.
        setattr(self, i + '_reshape', layers.Reshape(target_shape=(embedding_dim[i][1], ))(getattr(self, i + '_embedding')))

      # Input for the numerical variables.
      setattr(self, 'num_input', keras.Input(shape=(len(num_col),), name = 'num_col'))
      setattr(self, 'num_features', layers.Dense(64, activation='relu')(getattr(self, 'num_input')))

      # Input and embedding layers for the texts variable.
      setattr(self, 'text_input', keras.Input(shape=(None,), name = 'text'))
      setattr(self, 'text_embedding', layers.Embedding(1000, 64)(getattr(self, 'text_input')))

    def concat(self):

      # LSTM layer for the text data.
      text_features = layers.LSTM(128)(getattr(self, 'text_embedding'))
      
      # Reshape the text output so that the outputs can be concatenated
      text_features = layers.Reshape(target_shape=(128, ))(text_features)

      # Concatenate all outputs from previous layers.
      x = layers.concatenate([getattr(self, i + '_reshape') for i in cat_col_name] + [getattr(self, 'num_features')] + [text_features])

      # More dense layers.
      x = layers.Dense(128, activation="relu", name="dense1", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dropout(0.2)(x)
      x = layers.Dense(256, activation="relu", name="dense2", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dropout(0.2)(x)
      x = layers.Dense(128, activation="relu", name="dense3", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dense(64, activation="relu", name="dense4", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      pred = layers.Dense(1,  name="prediction")(x)

      # Compiling the model by specifying the inputs and outputs.
      model = keras.Model(
      inputs=[getattr(self, i + '_input') for i in cat_col_name] + [getattr(self, 'num_input')] + [getattr(self, 'text_input')],
      outputs=[pred])

      return model

# %% [markdown]
# For different outcome variables, we can just change the layer that generate the prediction, the loss and the metric.

# %% [markdown]
# For hyperparameter tuning, I think apart from changing the regular ones, we can also all more layers. Maybe some dense layer after the categorical embedding layer.

# %%
from tensorflow.keras import optimizers

def build_model(cat_col, cat_col_name, embedding_dim):

  # Instantiate the model.
  model = NN(cat_col, cat_col_name, embedding_dim)
  model = model.concat()
  
  sgd = optimizers.Adam(learning_rate=0.01)
  model.compile(
    optimizer=sgd,
    loss={
        "prediction": keras.losses.BinaryCrossentropy(from_logits=True)
        #"prediction": keras.losses.mean_squared_error 
    },
    #metrics=['mae']
    metrics=['acc']
)
  return model

# %%
# Instantiate the model.
model = build_model(cat_col, cat_col_name, embedding_dim)

# %%
# Check the dimensions and the graph of layers.
model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "model_78"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text (InputLayer)              [(None, None)]       0           []
#
#  track_id (InputLayer)          [(None, 1)]          0           []
#
#  program_number (InputLayer)    [(None, 1)]          0           []
#
#  jockey (InputLayer)            [(None, 1)]          0           []
#
#  course_type (InputLayer)       [(None, 1)]          0           []
#
#  track_condition (InputLayer)   [(None, 1)]          0           []
#
#  race_type (InputLayer)         [(None, 1)]          0           []
#
#  last_race_track (InputLayer)   [(None, 1)]          0           []
#
#  weathertype (InputLayer)       [(None, 1)]          0           []
#
#  embedding_725 (Embedding)      (None, None, 64)     64000       ['text[0][0]']
#
#  embedding_717 (Embedding)      (None, 1, 1)         3           ['track_id[0][0]']
#
#  embedding_718 (Embedding)      (None, 1, 10)        200         ['program_number[0][0]']
#
#  embedding_719 (Embedding)      (None, 1, 50)        8900        ['jockey[0][0]']
#
#  embedding_720 (Embedding)      (None, 1, 2)         10          ['course_type[0][0]']
#
#  embedding_721 (Embedding)      (None, 1, 3)         21          ['track_condition[0][0]']
#
#  embedding_722 (Embedding)      (None, 1, 6)         72          ['race_type[0][0]']
#
#  embedding_723 (Embedding)      (None, 1, 50)        9150        ['last_race_track[0][0]']
#
#  embedding_724 (Embedding)      (None, 1, 25)        1275        ['weathertype[0][0]']
#
#  num_col (InputLayer)           [(None, 10)]         0           []
#
#  lstm_79 (LSTM)                 (None, 128)          98816       ['embedding_725[0][0]']
#
#  reshape_717 (Reshape)          (None, 1)            0           ['embedding_717[0][0]']
#
#  reshape_718 (Reshape)          (None, 10)           0           ['embedding_718[0][0]']
#
#  reshape_719 (Reshape)          (None, 50)           0           ['embedding_719[0][0]']
#
#  reshape_720 (Reshape)          (None, 2)            0           ['embedding_720[0][0]']
#
#  reshape_721 (Reshape)          (None, 3)            0           ['embedding_721[0][0]']
#
#  reshape_722 (Reshape)          (None, 6)            0           ['embedding_722[0][0]']
#
#  reshape_723 (Reshape)          (None, 50)           0           ['embedding_723[0][0]']
#
#  reshape_724 (Reshape)          (None, 25)           0           ['embedding_724[0][0]']
#
#  dense_79 (Dense)               (None, 64)           704         ['num_col[0][0]']
#
#  reshape_725 (Reshape)          (None, 128)          0           ['lstm_79[0][0]']
#
#  concatenate_79 (Concatenate)   (None, 339)          0           ['reshape_717[0][0]',
#                                                                   'reshape_718[0][0]',
#                                                                   'reshape_719[0][0]',
#                                                                   'reshape_720[0][0]',
#                                                                   'reshape_721[0][0]',
#                                                                   'reshape_722[0][0]',
#                                                                   'reshape_723[0][0]',
#                                                                   'reshape_724[0][0]',
#                                                                   'dense_79[0][0]',
#                                                                   'reshape_725[0][0]']
#
#  dense1 (Dense)                 (None, 128)          43520       ['concatenate_79[0][0]']
#
#  dropout_192 (Dropout)          (None, 128)          0           ['dense1[0][0]']
#
#  dense2 (Dense)                 (None, 256)          33024       ['dropout_192[0][0]']
#
#  dropout_193 (Dropout)          (None, 256)          0           ['dense2[0][0]']
#
#  dense3 (Dense)                 (None, 128)          32896       ['dropout_193[0][0]']
#
#  dense4 (Dense)                 (None, 64)           8256        ['dense3[0][0]']
#
#  prediction (Dense)             (None, 1)            65          ['dense4[0][0]']
#
# ==================================================================================================
# Total params: 300,912
# Trainable params: 300,912
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# This function aims to turn the whole data numpy array to the form that the model can take.
def create_data(whole_data):

  output = {}
  for i in cat_col:
    output[i[0]] = whole_data[:,i[1]]
  output['num_col'] = whole_data[:,[j[1] for j in num_col]]
  output['text'] = whole_data[:, -15:]

  return output

# %%
# Here I did a 4-fold cross validation and log the loss and metric.
# Split the data.
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=1)

# Specify the hyperparameters.
k=4
num_val_samples = len(x_train) // k 
num_epochs = 50
batch_size = 1000
all_train_histories = [] 
all_val_histories = []


for i in range(k):
    print('processing fold #', i + 1)
    
    # Create the validation data and recreate the training data.
    val_data_temp = x_train[i * num_val_samples: (i + 1) * num_val_samples] 
    val_targets_temp = y_train[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate( [x_train[:i * num_val_samples],
        x_train[(i + 1) * num_val_samples:]], axis=0)
    partial_train_targets = np.concatenate( [y_train[:i * num_val_samples],
        y_train[(i + 1) * num_val_samples:]], axis=0)

    #Create the model and train.
    model = build_model(cat_col, cat_col_name, embedding_dim)

    # Create the model usable data inputs.
    train_data = create_data(partial_train_data)
    val_data = create_data(val_data_temp)

    # Train the model.
    history = model.fit(
    train_data,
    {"prediction": partial_train_targets[:, -1]},
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data=(val_data, val_targets_temp[:, -1])
)
    
    # Log the loss
    train_history = history.history['acc']
    val_history = history.history['val_acc']
    all_train_histories.append(train_history)
    all_val_histories.append(val_history)
# Out:
# processing fold # 1
# Epoch 1/50
# 10/10 [==============================] - 5s 149ms/step - loss: 0.7548 - acc: 0.4170 - val_loss: 0.5951 - val_acc: 0.1953
# Epoch 2/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.5340 - acc: 0.6782 - val_loss: 0.4935 - val_acc: 0.8047
# Epoch 3/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.4851 - acc: 0.8075 - val_loss: 0.4794 - val_acc: 0.8047
# Epoch 4/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4606 - acc: 0.8075 - val_loss: 0.4606 - val_acc: 0.8047
# Epoch 5/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4429 - acc: 0.8075 - val_loss: 0.4598 - val_acc: 0.8047
# Epoch 6/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.4337 - acc: 0.8075 - val_loss: 0.4593 - val_acc: 0.8047
# Epoch 7/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4196 - acc: 0.8075 - val_loss: 0.4739 - val_acc: 0.8047
# Epoch 8/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4070 - acc: 0.8019 - val_loss: 0.5142 - val_acc: 0.7868
# Epoch 9/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3986 - acc: 0.7797 - val_loss: 0.4869 - val_acc: 0.7609
# Epoch 10/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3863 - acc: 0.7703 - val_loss: 0.5423 - val_acc: 0.7643
# Epoch 11/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3819 - acc: 0.7793 - val_loss: 0.4893 - val_acc: 0.7540
# Epoch 12/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3706 - acc: 0.8006 - val_loss: 0.4941 - val_acc: 0.6810
# Epoch 13/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3700 - acc: 0.7782 - val_loss: 0.5316 - val_acc: 0.7540
# Epoch 14/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3607 - acc: 0.8087 - val_loss: 0.6307 - val_acc: 0.7464
# Epoch 15/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3501 - acc: 0.8129 - val_loss: 0.5597 - val_acc: 0.7702
# Epoch 16/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3381 - acc: 0.8244 - val_loss: 0.6615 - val_acc: 0.7659
# Epoch 17/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3356 - acc: 0.8224 - val_loss: 0.6892 - val_acc: 0.7656
# Epoch 18/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3253 - acc: 0.8318 - val_loss: 0.6567 - val_acc: 0.7533
# Epoch 19/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3122 - acc: 0.8455 - val_loss: 0.6407 - val_acc: 0.7367
# Epoch 20/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3159 - acc: 0.8424 - val_loss: 0.6792 - val_acc: 0.7258
# Epoch 21/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3031 - acc: 0.8470 - val_loss: 0.7403 - val_acc: 0.7324
# Epoch 22/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.2905 - acc: 0.8504 - val_loss: 0.7505 - val_acc: 0.7205
# Epoch 23/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2880 - acc: 0.8497 - val_loss: 0.7339 - val_acc: 0.7284
# Epoch 24/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2854 - acc: 0.8609 - val_loss: 0.6870 - val_acc: 0.7464
# Epoch 25/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.2816 - acc: 0.8633 - val_loss: 0.7238 - val_acc: 0.7543
# Epoch 26/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2592 - acc: 0.8741 - val_loss: 0.9380 - val_acc: 0.7457
# Epoch 27/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2407 - acc: 0.8821 - val_loss: 0.8990 - val_acc: 0.7457
# Epoch 28/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2519 - acc: 0.8773 - val_loss: 0.8189 - val_acc: 0.7507
# Epoch 29/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.2601 - acc: 0.8725 - val_loss: 0.8422 - val_acc: 0.7656
# Epoch 30/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2500 - acc: 0.8865 - val_loss: 1.0793 - val_acc: 0.7619
# Epoch 31/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.2432 - acc: 0.8830 - val_loss: 0.8706 - val_acc: 0.7586
# Epoch 32/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2332 - acc: 0.8897 - val_loss: 0.9422 - val_acc: 0.7424
# Epoch 33/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2180 - acc: 0.8971 - val_loss: 1.0928 - val_acc: 0.7576
# Epoch 34/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.2057 - acc: 0.9047 - val_loss: 1.1724 - val_acc: 0.7470
# Epoch 35/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2028 - acc: 0.9093 - val_loss: 1.0962 - val_acc: 0.7556
# Epoch 36/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1845 - acc: 0.9197 - val_loss: 0.9463 - val_acc: 0.7725
# Epoch 37/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2101 - acc: 0.9089 - val_loss: 1.1897 - val_acc: 0.7775
# Epoch 38/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.2178 - acc: 0.9093 - val_loss: 0.8651 - val_acc: 0.7656
# Epoch 39/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1904 - acc: 0.9200 - val_loss: 1.0289 - val_acc: 0.7656
# Epoch 40/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1824 - acc: 0.9244 - val_loss: 1.2143 - val_acc: 0.7470
# Epoch 41/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.1666 - acc: 0.9276 - val_loss: 1.3210 - val_acc: 0.7682
# Epoch 42/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1799 - acc: 0.9262 - val_loss: 1.0988 - val_acc: 0.7609
# Epoch 43/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1646 - acc: 0.9352 - val_loss: 1.2593 - val_acc: 0.7633
# Epoch 44/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.1579 - acc: 0.9379 - val_loss: 1.2338 - val_acc: 0.7483
# Epoch 45/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1979 - acc: 0.9169 - val_loss: 0.7898 - val_acc: 0.7725
# Epoch 46/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1872 - acc: 0.9275 - val_loss: 1.1090 - val_acc: 0.7570
# Epoch 47/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1745 - acc: 0.9317 - val_loss: 1.1138 - val_acc: 0.7619
# Epoch 48/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1560 - acc: 0.9376 - val_loss: 1.4196 - val_acc: 0.7672
# Epoch 49/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1587 - acc: 0.9395 - val_loss: 1.1610 - val_acc: 0.7596
# Epoch 50/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1456 - acc: 0.9463 - val_loss: 1.2600 - val_acc: 0.7444
# processing fold # 2
# Epoch 1/50
# 10/10 [==============================] - 4s 100ms/step - loss: 0.6849 - acc: 0.3916 - val_loss: 0.5926 - val_acc: 0.1916
# Epoch 2/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.5279 - acc: 0.6914 - val_loss: 0.4859 - val_acc: 0.8084
# Epoch 3/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4819 - acc: 0.8063 - val_loss: 0.4715 - val_acc: 0.8084
# Epoch 4/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4542 - acc: 0.8063 - val_loss: 0.4600 - val_acc: 0.8084
# Epoch 5/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.4362 - acc: 0.8063 - val_loss: 0.4927 - val_acc: 0.8084
# Epoch 6/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4230 - acc: 0.8063 - val_loss: 0.5116 - val_acc: 0.8084
# Epoch 7/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4097 - acc: 0.7791 - val_loss: 0.5689 - val_acc: 0.7689
# Epoch 8/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.4072 - acc: 0.7803 - val_loss: 0.4889 - val_acc: 0.7493
# Epoch 9/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3947 - acc: 0.7869 - val_loss: 0.5663 - val_acc: 0.7692
# Epoch 10/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3889 - acc: 0.7886 - val_loss: 0.5246 - val_acc: 0.7570
# Epoch 11/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3798 - acc: 0.7928 - val_loss: 0.5524 - val_acc: 0.7490
# Epoch 12/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3720 - acc: 0.7945 - val_loss: 0.5796 - val_acc: 0.7298
# Epoch 13/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3596 - acc: 0.8038 - val_loss: 0.5661 - val_acc: 0.7172
# Epoch 14/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3567 - acc: 0.8011 - val_loss: 0.6274 - val_acc: 0.7125
# Epoch 15/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3506 - acc: 0.8070 - val_loss: 0.6652 - val_acc: 0.7669
# Epoch 16/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3480 - acc: 0.8111 - val_loss: 0.7008 - val_acc: 0.7357
# Epoch 17/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3323 - acc: 0.8238 - val_loss: 0.6832 - val_acc: 0.7573
# Epoch 18/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3225 - acc: 0.8286 - val_loss: 0.6249 - val_acc: 0.7347
# Epoch 19/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3387 - acc: 0.8236 - val_loss: 0.5934 - val_acc: 0.7570
# Epoch 20/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3157 - acc: 0.8450 - val_loss: 0.7095 - val_acc: 0.7523
# Epoch 21/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3046 - acc: 0.8436 - val_loss: 0.7374 - val_acc: 0.7434
# Epoch 22/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3006 - acc: 0.8578 - val_loss: 0.6942 - val_acc: 0.7619
# Epoch 23/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2963 - acc: 0.8532 - val_loss: 0.6934 - val_acc: 0.7331
# Epoch 24/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2919 - acc: 0.8612 - val_loss: 0.5672 - val_acc: 0.7662
# Epoch 25/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2768 - acc: 0.8716 - val_loss: 0.7494 - val_acc: 0.7450
# Epoch 26/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2524 - acc: 0.8798 - val_loss: 0.8089 - val_acc: 0.7212
# Epoch 27/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2508 - acc: 0.8777 - val_loss: 0.7792 - val_acc: 0.7543
# Epoch 28/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2618 - acc: 0.8758 - val_loss: 0.9053 - val_acc: 0.7407
# Epoch 29/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2469 - acc: 0.8853 - val_loss: 0.7547 - val_acc: 0.7576
# Epoch 30/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2399 - acc: 0.8831 - val_loss: 1.0029 - val_acc: 0.7788
# Epoch 31/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2400 - acc: 0.8911 - val_loss: 0.8777 - val_acc: 0.7848
# Epoch 32/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2331 - acc: 0.8958 - val_loss: 0.9463 - val_acc: 0.7616
# Epoch 33/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2150 - acc: 0.9077 - val_loss: 1.0572 - val_acc: 0.7659
# Epoch 34/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2090 - acc: 0.9096 - val_loss: 0.9939 - val_acc: 0.7656
# Epoch 35/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.1887 - acc: 0.9224 - val_loss: 1.1764 - val_acc: 0.7590
# Epoch 36/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1799 - acc: 0.9224 - val_loss: 1.3509 - val_acc: 0.7583
# Epoch 37/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.1753 - acc: 0.9268 - val_loss: 1.3737 - val_acc: 0.7507
# Epoch 38/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1734 - acc: 0.9283 - val_loss: 1.3199 - val_acc: 0.7629
# Epoch 39/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1678 - acc: 0.9296 - val_loss: 1.5464 - val_acc: 0.7838
# Epoch 40/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1610 - acc: 0.9349 - val_loss: 1.4860 - val_acc: 0.7762
# Epoch 41/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1516 - acc: 0.9409 - val_loss: 1.4263 - val_acc: 0.7639
# Epoch 42/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1714 - acc: 0.9316 - val_loss: 1.2990 - val_acc: 0.7696
# Epoch 43/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1618 - acc: 0.9353 - val_loss: 1.2012 - val_acc: 0.7643
# Epoch 44/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1351 - acc: 0.9472 - val_loss: 1.4991 - val_acc: 0.7689
# Epoch 45/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.1382 - acc: 0.9473 - val_loss: 1.3963 - val_acc: 0.7626
# Epoch 46/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1690 - acc: 0.9353 - val_loss: 1.0900 - val_acc: 0.7769
# Epoch 47/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1491 - acc: 0.9435 - val_loss: 1.3533 - val_acc: 0.7623
# Epoch 48/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1327 - acc: 0.9547 - val_loss: 1.4614 - val_acc: 0.7653
# Epoch 49/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1450 - acc: 0.9472 - val_loss: 1.3263 - val_acc: 0.7702
# Epoch 50/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1253 - acc: 0.9577 - val_loss: 1.5276 - val_acc: 0.7745
# processing fold # 3
# Epoch 1/50
# 10/10 [==============================] - 4s 100ms/step - loss: 0.7193 - acc: 0.4109 - val_loss: 0.6096 - val_acc: 0.1890
# Epoch 2/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.5491 - acc: 0.6176 - val_loss: 0.4992 - val_acc: 0.8110
# Epoch 3/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4939 - acc: 0.8054 - val_loss: 0.4732 - val_acc: 0.8110
# Epoch 4/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.4702 - acc: 0.8054 - val_loss: 0.4546 - val_acc: 0.8110
# Epoch 5/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.4476 - acc: 0.8054 - val_loss: 0.4497 - val_acc: 0.8097
# Epoch 6/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4281 - acc: 0.7956 - val_loss: 0.4562 - val_acc: 0.7357
# Epoch 7/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.4145 - acc: 0.7698 - val_loss: 0.6167 - val_acc: 0.8117
# Epoch 8/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.4385 - acc: 0.7753 - val_loss: 0.4557 - val_acc: 0.7954
# Epoch 9/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.4106 - acc: 0.7964 - val_loss: 0.4680 - val_acc: 0.7503
# Epoch 10/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3974 - acc: 0.7842 - val_loss: 0.4613 - val_acc: 0.7115
# Epoch 11/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4023 - acc: 0.8017 - val_loss: 0.4555 - val_acc: 0.7139
# Epoch 12/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3881 - acc: 0.8023 - val_loss: 0.4611 - val_acc: 0.7371
# Epoch 13/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3768 - acc: 0.8103 - val_loss: 0.4988 - val_acc: 0.7470
# Epoch 14/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3609 - acc: 0.8155 - val_loss: 0.5236 - val_acc: 0.7231
# Epoch 15/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3598 - acc: 0.8039 - val_loss: 0.5267 - val_acc: 0.7517
# Epoch 16/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3537 - acc: 0.8193 - val_loss: 0.5941 - val_acc: 0.7440
# Epoch 17/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3427 - acc: 0.8207 - val_loss: 0.6191 - val_acc: 0.7507
# Epoch 18/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3417 - acc: 0.8098 - val_loss: 0.6016 - val_acc: 0.7460
# Epoch 19/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3399 - acc: 0.8296 - val_loss: 0.6391 - val_acc: 0.7397
# Epoch 20/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3345 - acc: 0.8233 - val_loss: 0.5718 - val_acc: 0.7487
# Epoch 21/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3203 - acc: 0.8433 - val_loss: 0.7011 - val_acc: 0.7281
# Epoch 22/50
# 10/10 [==============================] - 0s 34ms/step - loss: 0.3102 - acc: 0.8420 - val_loss: 0.6609 - val_acc: 0.7410
# Epoch 23/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.3065 - acc: 0.8539 - val_loss: 0.7790 - val_acc: 0.7566
# Epoch 24/50
# 10/10 [==============================] - 0s 32ms/step - loss: 0.3062 - acc: 0.8433 - val_loss: 0.8353 - val_acc: 0.7666
# Epoch 25/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.3027 - acc: 0.8428 - val_loss: 1.0713 - val_acc: 0.7560
# Epoch 26/50
# 10/10 [==============================] - 0s 36ms/step - loss: 0.3088 - acc: 0.8523 - val_loss: 0.6930 - val_acc: 0.7696
# Epoch 27/50
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2991 - acc: 0.8496 - val_loss: 0.8008 - val_acc: 0.7487
# Epoch 28/50
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2904 - acc: 0.8579 - val_loss: 0.7055 - val_acc: 0.7288
# Epoch 29/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.2910 - acc: 0.8583 - val_loss: 0.7435 - val_acc: 0.7477
# Epoch 30/50
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2765 - acc: 0.8706 - val_loss: 0.7749 - val_acc: 0.7527
# Epoch 31/50
# 10/10 [==============================] - 0s 36ms/step - loss: 0.2595 - acc: 0.8779 - val_loss: 0.8959 - val_acc: 0.7394
# Epoch 32/50
# 10/10 [==============================] - 0s 32ms/step - loss: 0.2486 - acc: 0.8844 - val_loss: 0.8850 - val_acc: 0.7387
# Epoch 33/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.2526 - acc: 0.8849 - val_loss: 1.0572 - val_acc: 0.7410
# Epoch 34/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.2484 - acc: 0.8869 - val_loss: 0.8707 - val_acc: 0.7281
# Epoch 35/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2634 - acc: 0.8757 - val_loss: 0.7752 - val_acc: 0.7341
# Epoch 36/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.2556 - acc: 0.8832 - val_loss: 0.8223 - val_acc: 0.7228
# Epoch 37/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2440 - acc: 0.8870 - val_loss: 0.7779 - val_acc: 0.7294
# Epoch 38/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2454 - acc: 0.8865 - val_loss: 0.9888 - val_acc: 0.7454
# Epoch 39/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2297 - acc: 0.8970 - val_loss: 0.8830 - val_acc: 0.7440
# Epoch 40/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2303 - acc: 0.9002 - val_loss: 0.8128 - val_acc: 0.7454
# Epoch 41/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2250 - acc: 0.9024 - val_loss: 0.8665 - val_acc: 0.7510
# Epoch 42/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2029 - acc: 0.9095 - val_loss: 1.0367 - val_acc: 0.7324
# Epoch 43/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1971 - acc: 0.9121 - val_loss: 1.0757 - val_acc: 0.7497
# Epoch 44/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2065 - acc: 0.9135 - val_loss: 1.0524 - val_acc: 0.7434
# Epoch 45/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2017 - acc: 0.9136 - val_loss: 1.0553 - val_acc: 0.7593
# Epoch 46/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.1943 - acc: 0.9210 - val_loss: 0.9596 - val_acc: 0.7626
# Epoch 47/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1776 - acc: 0.9274 - val_loss: 1.1932 - val_acc: 0.7563
# Epoch 48/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1618 - acc: 0.9358 - val_loss: 1.2570 - val_acc: 0.7580
# Epoch 49/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1520 - acc: 0.9381 - val_loss: 1.2750 - val_acc: 0.7566
# Epoch 50/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1558 - acc: 0.9368 - val_loss: 1.1735 - val_acc: 0.7510
# processing fold # 4
# Epoch 1/50
# 10/10 [==============================] - 5s 99ms/step - loss: 0.6222 - acc: 0.4013 - val_loss: 0.5154 - val_acc: 0.8031
# Epoch 2/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.5026 - acc: 0.8080 - val_loss: 0.4913 - val_acc: 0.8031
# Epoch 3/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.4738 - acc: 0.8080 - val_loss: 0.4739 - val_acc: 0.8031
# Epoch 4/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4408 - acc: 0.8092 - val_loss: 0.4660 - val_acc: 0.6694
# Epoch 5/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.4181 - acc: 0.7788 - val_loss: 0.4756 - val_acc: 0.7354
# Epoch 6/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4006 - acc: 0.7902 - val_loss: 0.4903 - val_acc: 0.7314
# Epoch 7/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3988 - acc: 0.7914 - val_loss: 0.4784 - val_acc: 0.7056
# Epoch 8/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3834 - acc: 0.8112 - val_loss: 0.4979 - val_acc: 0.7175
# Epoch 9/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.3686 - acc: 0.8152 - val_loss: 0.5017 - val_acc: 0.6824
# Epoch 10/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3781 - acc: 0.8158 - val_loss: 0.5178 - val_acc: 0.6834
# Epoch 11/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3746 - acc: 0.8143 - val_loss: 0.4898 - val_acc: 0.7586
# Epoch 12/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3563 - acc: 0.8192 - val_loss: 0.5891 - val_acc: 0.7570
# Epoch 13/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3374 - acc: 0.8339 - val_loss: 0.5719 - val_acc: 0.7593
# Epoch 14/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3276 - acc: 0.8487 - val_loss: 0.6071 - val_acc: 0.7583
# Epoch 15/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3096 - acc: 0.8522 - val_loss: 0.6889 - val_acc: 0.7732
# Epoch 16/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3084 - acc: 0.8568 - val_loss: 0.6861 - val_acc: 0.7623
# Epoch 17/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3005 - acc: 0.8575 - val_loss: 0.6825 - val_acc: 0.7401
# Epoch 18/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2976 - acc: 0.8607 - val_loss: 0.6323 - val_acc: 0.7374
# Epoch 19/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2914 - acc: 0.8630 - val_loss: 0.6487 - val_acc: 0.7629
# Epoch 20/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2884 - acc: 0.8651 - val_loss: 0.6872 - val_acc: 0.7374
# Epoch 21/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.2736 - acc: 0.8754 - val_loss: 0.6996 - val_acc: 0.7510
# Epoch 22/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2587 - acc: 0.8812 - val_loss: 0.8729 - val_acc: 0.7457
# Epoch 23/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2508 - acc: 0.8810 - val_loss: 0.8319 - val_acc: 0.7603
# Epoch 24/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2522 - acc: 0.8809 - val_loss: 1.1048 - val_acc: 0.7397
# Epoch 25/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2534 - acc: 0.8822 - val_loss: 0.8502 - val_acc: 0.7593
# Epoch 26/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2454 - acc: 0.8869 - val_loss: 1.1276 - val_acc: 0.7639
# Epoch 27/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2399 - acc: 0.8887 - val_loss: 0.9321 - val_acc: 0.7440
# Epoch 28/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2114 - acc: 0.9055 - val_loss: 1.1203 - val_acc: 0.7338
# Epoch 29/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2049 - acc: 0.9090 - val_loss: 1.0551 - val_acc: 0.7371
# Epoch 30/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2097 - acc: 0.9027 - val_loss: 1.2930 - val_acc: 0.7384
# Epoch 31/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1992 - acc: 0.9118 - val_loss: 0.9641 - val_acc: 0.7457
# Epoch 32/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1946 - acc: 0.9182 - val_loss: 1.1829 - val_acc: 0.7689
# Epoch 33/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2352 - acc: 0.8950 - val_loss: 0.7576 - val_acc: 0.7553
# Epoch 34/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2170 - acc: 0.9101 - val_loss: 0.8419 - val_acc: 0.7364
# Epoch 35/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.2301 - acc: 0.9008 - val_loss: 0.7637 - val_acc: 0.7457
# Epoch 36/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2127 - acc: 0.9146 - val_loss: 0.9371 - val_acc: 0.7464
# Epoch 37/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1952 - acc: 0.9166 - val_loss: 0.9161 - val_acc: 0.7570
# Epoch 38/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1882 - acc: 0.9233 - val_loss: 0.9974 - val_acc: 0.7470
# Epoch 39/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1884 - acc: 0.9178 - val_loss: 1.0971 - val_acc: 0.7580
# Epoch 40/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.1894 - acc: 0.9244 - val_loss: 1.0077 - val_acc: 0.7444
# Epoch 41/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.1772 - acc: 0.9272 - val_loss: 1.1237 - val_acc: 0.7523
# Epoch 42/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1782 - acc: 0.9244 - val_loss: 1.0668 - val_acc: 0.7550
# Epoch 43/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.1596 - acc: 0.9344 - val_loss: 1.5221 - val_acc: 0.7682
# Epoch 44/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.1366 - acc: 0.9515 - val_loss: 1.5584 - val_acc: 0.7603
# Epoch 45/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1396 - acc: 0.9462 - val_loss: 1.6010 - val_acc: 0.7616
# Epoch 46/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.1405 - acc: 0.9486 - val_loss: 1.2551 - val_acc: 0.7679
# Epoch 47/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1310 - acc: 0.9534 - val_loss: 1.6184 - val_acc: 0.7560
# Epoch 48/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1182 - acc: 0.9604 - val_loss: 1.6707 - val_acc: 0.7543
# Epoch 49/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.1160 - acc: 0.9603 - val_loss: 1.5834 - val_acc: 0.7619
# Epoch 50/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.1074 - acc: 0.9640 - val_loss: 1.8275 - val_acc: 0.7477

# %%
# Calculate the average accuracy acorss validations.
average_train_history = [
    np.mean([x[i] for x in  all_train_histories]) for i in range(num_epochs)]

average_val_history = [
    np.mean([x[i] for x in all_val_histories]) for i in range(num_epochs)]

# %%
# Define a function to smooth the history of loss.
def smooth_curve(points, factor=0.9):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)
  return smoothed_points

# %%
smooth_history1 = smooth_curve(average_train_history)
smooth_history2 = smooth_curve(average_val_history)

# Plot the smmoothed history.
plt.plot(range(1, len(smooth_history1) + 1), smooth_history1, label = 'training')
plt.plot(range(1, len(smooth_history2) + 1), smooth_history2, label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('NN_acc_win.png')
plt.show()

# %%
train_data = create_data(x_train)
test_data = create_data(x_test)

# Train the final model.
model = build_model(cat_col, cat_col_name, embedding_dim)
model.fit(
    train_data,
    {"prediction": y_train[:, -1]},
    epochs=50,
    batch_size=1000)

# Print out the final results.
model.evaluate(train_data, y_train[:, -1])
model.evaluate(test_data, y_test[:, -1])
# Out:
# Epoch 1/50
# 13/13 [==============================] - 3s 18ms/step - loss: 0.5582 - acc: 0.5971
# Epoch 2/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4812 - acc: 0.8068
# Epoch 3/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.4445 - acc: 0.8069
# Epoch 4/50
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4252 - acc: 0.7995
# Epoch 5/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.4086 - acc: 0.7826
# Epoch 6/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3990 - acc: 0.7953
# Epoch 7/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3855 - acc: 0.7910
# Epoch 8/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3703 - acc: 0.8132
# Epoch 9/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3583 - acc: 0.8123
# Epoch 10/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3430 - acc: 0.8268
# Epoch 11/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3297 - acc: 0.8311
# Epoch 12/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3131 - acc: 0.8420
# Epoch 13/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3059 - acc: 0.8481
# Epoch 14/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2937 - acc: 0.8525
# Epoch 15/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2800 - acc: 0.8594
# Epoch 16/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2716 - acc: 0.8668
# Epoch 17/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2504 - acc: 0.8854
# Epoch 18/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2498 - acc: 0.8805
# Epoch 19/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2451 - acc: 0.8881
# Epoch 20/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2304 - acc: 0.8865
# Epoch 21/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2355 - acc: 0.8937
# Epoch 22/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2232 - acc: 0.8990
# Epoch 23/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2228 - acc: 0.9016
# Epoch 24/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2126 - acc: 0.9039
# Epoch 25/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1940 - acc: 0.9161
# Epoch 26/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1757 - acc: 0.9251
# Epoch 27/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1653 - acc: 0.9323
# Epoch 28/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1612 - acc: 0.9339
# Epoch 29/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1734 - acc: 0.9242
# Epoch 30/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1561 - acc: 0.9359
# Epoch 31/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.1468 - acc: 0.9442
# Epoch 32/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1541 - acc: 0.9415
# Epoch 33/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1322 - acc: 0.9500
# Epoch 34/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1185 - acc: 0.9574
# Epoch 35/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1203 - acc: 0.9586
# Epoch 36/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1149 - acc: 0.9596
# Epoch 37/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1206 - acc: 0.9576
# Epoch 38/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1143 - acc: 0.9600
# Epoch 39/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1108 - acc: 0.9620
# Epoch 40/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1014 - acc: 0.9670
# Epoch 41/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1076 - acc: 0.9666
# Epoch 42/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1360 - acc: 0.9560
# Epoch 43/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.1304 - acc: 0.9569
# Epoch 44/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1106 - acc: 0.9650
# Epoch 45/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1101 - acc: 0.9645
# Epoch 46/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1130 - acc: 0.9629
# Epoch 47/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0960 - acc: 0.9703
# Epoch 48/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0819 - acc: 0.9762
# Epoch 49/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0933 - acc: 0.9721
# Epoch 50/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1110 - acc: 0.9641
# 377/377 [==============================] - 2s 4ms/step - loss: 0.0676 - acc: 0.9855
# 95/95 [==============================] - 1s 5ms/step - loss: 0.9870 - acc: 0.7839
# [0.9869565367698669, 0.7838912606239319]
