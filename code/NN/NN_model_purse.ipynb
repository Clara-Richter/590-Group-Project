# %%
# !pip install wordninja
# !pip install num2words

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import regularizers
from sklearn import preprocessing
import wordninja
from nltk.tokenize import RegexpTokenizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import re
import num2words
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

pd.set_option('display.max_columns', None)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wordninja
#   Downloading wordninja-2.0.0.tar.gz (541 kB)
#      |████████████████████████████████| 541 kB 25.4 MB/s
# Building wheels for collected packages: wordninja
#   Building wheel for wordninja (setup.py) ... done
#   Created wheel for wordninja: filename=wordninja-2.0.0-py3-none-any.whl size=541552 sha256=fef2409bee52406e7d0ddcbca7e45c6e4620901ff642057ade97e69c5e8d6aab
#   Stored in directory: /root/.cache/pip/wheels/a6/08/fb/98831d1c2702c8352a339f91104515eab5d7906d4118eeeaed
# Successfully built wordninja
# Installing collected packages: wordninja
# Successfully installed wordninja-2.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting num2words
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 9.7 MB/s
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=e1221ec9c501aa4306008ea933d3aa850081970b20aab91e18adc27fbca9ad0f
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.12
# Mounted at /content/drive

# %%
# Specify the path to our shared drive. Should work for all of us.
path = '/content/drive/Shareddrives/ANLY590_GROUP_4_PROJECT'

# %%
df = pd.read_csv(path + "/data/merged_data/joined_data_without_position.csv", index_col=0)

# %% [markdown]
# ## Preprocessing

# %%
# Create win dummy variable.
df['win'] = np.where(df['race_number'] >= 3, 1, 0)

# Drop the redundant variables.
df = df.drop(['position_at_finish', 'post_time', 'distance_id'], axis = 1)

# Convert the race number as string.
df['race_number'] = df['race_number'].astype('str')

# Convert to float and fill NA
df['day_since_last_race'] = df['day_since_last_race'].apply(lambda x : x[:-5] if x is not np.nan else np.nan).astype('float').fillna(0)

# Fill the comments column with string None.
df['Comments'] = df['Comments'].fillna('None')

# %%
# Preprocess the comments. 
res = []
tokenizer = RegexpTokenizer(r'\w+')
for i in df.Comments:
  if type(i) == str:
    re.sub(r"(\d+)", lambda x: num2words.num2words(int(x.group(0))), i)
    phrase_list = tokenizer.tokenize(i)
    splited_tokens = [wordninja.split(i) for i in phrase_list]
    flat_splited_tokens = [j for sublist in splited_tokens for j in sublist]
    res.append(flat_splited_tokens)    
  else:
    res.append(np.nan)

df['Comments'] = res

# %%
# Convert all numerical columns to float.
for i in df.columns:
  if df[i].dtype == int:
    df[i] = df[i].astype('float')

# %% [markdown]
# Here I concat all three outcome variables, so when training, be mindful about the column index

# %%
# Separate the target data and others.
# removing extra variables
target = df[['purse']]
data = df.drop(['win', 'odds', 'purse','Comments', "seconds_in_race", "race_number", "race_date"], axis = 1)

# %%
# Separate the training data to numericals, categoricals and the text.
cat_col = []
num_col = []

for i in data.columns:
  if data[i].dtype == object:
    cat_col.append((i, data.columns.get_loc(i)))

  elif data[i].dtype == float:
    num_col.append((i, data.columns.get_loc(i)))

# %%
# Label encode the categorical variables and standarlize the numericals. 
for i in cat_col:
  le = preprocessing.LabelEncoder()
  data[i[0]] = le.fit_transform(data[i[0]])

num_col_name = [j[0] for j in num_col]
cat_col_name = [j[0] for j in cat_col]

se = preprocessing.StandardScaler()
data[num_col_name] = se.fit_transform(data[num_col_name])

se = preprocessing.StandardScaler()
target[['purse']] = se.fit_transform(target[['purse']])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
# Create a dict for the unique categories and the desired embedding dimensions for each categorical variable. 
# Jeremy Howard provides the following rule of thumb; embedding size = min(50, number of categories/2).
def create_embedding_dim():

  embedding_dim = {}
  for i in range(len(cat_col)):
    embedding_dim[cat_col[i][0]] = (data[cat_col[i][0]].nunique(), min(50, data[cat_col[i][0]].nunique() //2 ))

  return embedding_dim

# %%
embedding_dim = create_embedding_dim()

# %%
# Convert the comments column to tokes and pad each sequence.

max_words = 1133 # The length of the vocabulary.

# Make the units matrices.
tokenizer = Tokenizer(max_words)
tokenizer.fit_on_texts(df['Comments'])
data_text = tokenizer.texts_to_sequences(df['Comments'])

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# Maximum length for a vector.
maxlen = 15

# Pad the sequence.
data_text = pad_sequences(data_text, maxlen=maxlen)

print('Shape of data tensor:', data_text.shape)
# Out:
# Found 1133 unique tokens.
# Shape of data tensor: (15081, 15)

# %%
# Concat the regular features with text features. Transform them all to numpy array.
data = np.concatenate((np.asarray(data), data_text), axis=1)
target = np.asarray(target)

# %% [markdown]
# ## Modeling

# %% [markdown]
# Here I build the model mainly with a class and Keras functional API for it will allow us to build a more flexible model.

# %%
class NN():

    def __init__(self, cat_col, cat_col_name, embedding_dim):
      # For each categorical variable, we need to specify a input layer and a embedding layer. So I created them all by iteratively specifying them as attributes.
      for i in cat_col_name:

        # These are all the input layers for the cat_col
        setattr(self, i + '_input', keras.Input(shape=(1,), name=i))

        #Then we embed them by the dimensions we created earlier.
        setattr(self, i + '_embedding', layers.Embedding(embedding_dim[i][0], embedding_dim[i][1], input_length = 1)(getattr(self, i + '_input')))

        # Next we rehsape them so that they can be concatenated with other layers' output.
        setattr(self, i + '_reshape', layers.Reshape(target_shape=(embedding_dim[i][1], ))(getattr(self, i + '_embedding')))

      # Input for the numerical variables.
      setattr(self, 'num_input', keras.Input(shape=(len(num_col),), name = 'num_col'))
      setattr(self, 'num_features', layers.Dense(64, activation='relu')(getattr(self, 'num_input')))

      # Input and embedding layers for the texts variable.
      setattr(self, 'text_input', keras.Input(shape=(None,), name = 'text'))
      setattr(self, 'text_embedding', layers.Embedding(1000, 64)(getattr(self, 'text_input')))

    def concat(self):

      # LSTM layer for the text data.
      text_features = layers.LSTM(128)(getattr(self, 'text_embedding'))
      
      # Reshape the text output so that the outputs can be concatenated
      text_features = layers.Reshape(target_shape=(128, ))(text_features)

      # Concatenate all outputs from previous layers.
      x = layers.concatenate([getattr(self, i + '_reshape') for i in cat_col_name] + [getattr(self, 'num_features')] + [text_features])

      # More dense layers.
      x = layers.Dense(128, activation="relu", name="dense1", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dropout(0.2)(x)
      x = layers.Dense(256, activation="relu", name="dense2", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dropout(0.2)(x)
      x = layers.Dense(128, activation="relu", name="dense3", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      x = layers.Dense(64, activation="relu", name="dense4", kernel_initializer='normal',
                       kernel_regularizer=regularizers.l2(0.00001))(x)
      pred = layers.Dense(1,  name="prediction")(x)

      # Compiling the model by specifying the inputs and outputs.
      model = keras.Model(
      inputs=[getattr(self, i + '_input') for i in cat_col_name] + [getattr(self, 'num_input')] + [getattr(self, 'text_input')],
      outputs=[pred])

      return model

# %% [markdown]
# For different outcome variables, we can just change the layer that generate the prediction, the loss and the metric.

# %% [markdown]
# For hyperparameter tuning, I think apart from changing the regular ones, we can also all more layers. Maybe some dense layer after the categorical embedding layer.

# %%
from tensorflow.keras import optimizers

def build_model(cat_col, cat_col_name, embedding_dim):

  # Instantiate the model.
  model = NN(cat_col, cat_col_name, embedding_dim)
  model = model.concat()

  opt = optimizers.Adam(learning_rate=0.01)

  model.compile(
    optimizer=opt,
    loss={
        #"prediction": keras.losses.BinaryCrossentropy(from_logits=True)
        "prediction": keras.losses.mean_squared_error 
    },
    metrics=['mae']
    #metrics=['acc']
)
  return model

# %%
# Instantiate the model.
model = build_model(cat_col, cat_col_name, embedding_dim)

# %%
# Check the dimensions and the graph of layers.
model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text (InputLayer)              [(None, None)]       0           []
#
#  track_id (InputLayer)          [(None, 1)]          0           []
#
#  program_number (InputLayer)    [(None, 1)]          0           []
#
#  jockey (InputLayer)            [(None, 1)]          0           []
#
#  course_type (InputLayer)       [(None, 1)]          0           []
#
#  track_condition (InputLayer)   [(None, 1)]          0           []
#
#  race_type (InputLayer)         [(None, 1)]          0           []
#
#  last_race_track (InputLayer)   [(None, 1)]          0           []
#
#  weathertype (InputLayer)       [(None, 1)]          0           []
#
#  embedding_8 (Embedding)        (None, None, 64)     64000       ['text[0][0]']
#
#  embedding (Embedding)          (None, 1, 1)         3           ['track_id[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 10)        200         ['program_number[0][0]']
#
#  embedding_2 (Embedding)        (None, 1, 50)        8900        ['jockey[0][0]']
#
#  embedding_3 (Embedding)        (None, 1, 2)         10          ['course_type[0][0]']
#
#  embedding_4 (Embedding)        (None, 1, 3)         21          ['track_condition[0][0]']
#
#  embedding_5 (Embedding)        (None, 1, 6)         72          ['race_type[0][0]']
#
#  embedding_6 (Embedding)        (None, 1, 50)        9150        ['last_race_track[0][0]']
#
#  embedding_7 (Embedding)        (None, 1, 25)        1275        ['weathertype[0][0]']
#
#  num_col (InputLayer)           [(None, 10)]         0           []
#
#  lstm (LSTM)                    (None, 128)          98816       ['embedding_8[0][0]']
#
#  reshape (Reshape)              (None, 1)            0           ['embedding[0][0]']
#
#  reshape_1 (Reshape)            (None, 10)           0           ['embedding_1[0][0]']
#
#  reshape_2 (Reshape)            (None, 50)           0           ['embedding_2[0][0]']
#
#  reshape_3 (Reshape)            (None, 2)            0           ['embedding_3[0][0]']
#
#  reshape_4 (Reshape)            (None, 3)            0           ['embedding_4[0][0]']
#
#  reshape_5 (Reshape)            (None, 6)            0           ['embedding_5[0][0]']
#
#  reshape_6 (Reshape)            (None, 50)           0           ['embedding_6[0][0]']
#
#  reshape_7 (Reshape)            (None, 25)           0           ['embedding_7[0][0]']
#
#  dense (Dense)                  (None, 64)           704         ['num_col[0][0]']
#
#  reshape_8 (Reshape)            (None, 128)          0           ['lstm[0][0]']
#
#  concatenate (Concatenate)      (None, 339)          0           ['reshape[0][0]',
#                                                                   'reshape_1[0][0]',
#                                                                   'reshape_2[0][0]',
#                                                                   'reshape_3[0][0]',
#                                                                   'reshape_4[0][0]',
#                                                                   'reshape_5[0][0]',
#                                                                   'reshape_6[0][0]',
#                                                                   'reshape_7[0][0]',
#                                                                   'dense[0][0]',
#                                                                   'reshape_8[0][0]']
#
#  dense1 (Dense)                 (None, 128)          43520       ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense1[0][0]']
#
#  dense2 (Dense)                 (None, 256)          33024       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense2[0][0]']
#
#  dense3 (Dense)                 (None, 128)          32896       ['dropout_1[0][0]']
#
#  dense4 (Dense)                 (None, 64)           8256        ['dense3[0][0]']
#
#  prediction (Dense)             (None, 1)            65          ['dense4[0][0]']
#
# ==================================================================================================
# Total params: 300,912
# Trainable params: 300,912
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# This function aims to turn the whole data numpy array to the form that the model can take.
def create_data(whole_data):

  output = {}
  for i in cat_col:
    output[i[0]] = whole_data[:,i[1]]
  output['num_col'] = whole_data[:,[j[1] for j in num_col]]
  output['text'] = whole_data[:, -15:]

  return output

# %%
# Here I did a 4-fold cross validation and log the loss and metric.
# Split the data.
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=1)

# Specify the hyperparameters.
k=4
num_val_samples = len(x_train) // k 
num_epochs = 50
batch_size = 1000
all_train_histories = [] 
all_val_histories = []


for i in range(k):
    print('processing fold #', i + 1)
    
    # Create the validation data and recreate the training data.
    val_data_temp = x_train[i * num_val_samples: (i + 1) * num_val_samples] 
    val_targets_temp = y_train[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate( [x_train[:i * num_val_samples],
        x_train[(i + 1) * num_val_samples:]], axis=0)
    partial_train_targets = np.concatenate( [y_train[:i * num_val_samples],
        y_train[(i + 1) * num_val_samples:]], axis=0)

    #Create the model and train.
    model = build_model(cat_col, cat_col_name, embedding_dim)

    # Create the model usable data inputs.
    train_data = create_data(partial_train_data)
    val_data = create_data(val_data_temp)

    # Train the model.
    history = model.fit(
    train_data,
    {"prediction": partial_train_targets[:, -1]},
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data=(val_data, val_targets_temp[:, -1])
)
    
    # Log the loss
    train_history = history.history['mae']
    val_history = history.history['val_mae']
    all_train_histories.append(train_history)
    all_val_histories.append(val_history)
# Out:
# processing fold # 1
# Epoch 1/50
# 10/10 [==============================] - 13s 189ms/step - loss: 1.1558 - mae: 0.4880 - val_loss: 1.0648 - val_mae: 0.4230
# Epoch 2/50
# 10/10 [==============================] - 0s 51ms/step - loss: 1.0429 - mae: 0.3987 - val_loss: 1.0352 - val_mae: 0.3385
# Epoch 3/50
# 10/10 [==============================] - 0s 42ms/step - loss: 0.9972 - mae: 0.3787 - val_loss: 0.9494 - val_mae: 0.3296
# Epoch 4/50
# 10/10 [==============================] - 0s 34ms/step - loss: 0.6422 - mae: 0.2905 - val_loss: 0.3744 - val_mae: 0.2536
# Epoch 5/50
# 10/10 [==============================] - 0s 36ms/step - loss: 0.3289 - mae: 0.2381 - val_loss: 0.3231 - val_mae: 0.2091
# Epoch 6/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.2498 - mae: 0.2014 - val_loss: 0.3190 - val_mae: 0.2112
# Epoch 7/50
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2033 - mae: 0.1726 - val_loss: 0.3007 - val_mae: 0.1922
# Epoch 8/50
# 10/10 [==============================] - 0s 43ms/step - loss: 0.1785 - mae: 0.1624 - val_loss: 0.2950 - val_mae: 0.1998
# Epoch 9/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1737 - mae: 0.1537 - val_loss: 0.4036 - val_mae: 0.2174
# Epoch 10/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1865 - mae: 0.1576 - val_loss: 0.3387 - val_mae: 0.2017
# Epoch 11/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1618 - mae: 0.1531 - val_loss: 0.3520 - val_mae: 0.1913
# Epoch 12/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2506 - mae: 0.1709 - val_loss: 0.3250 - val_mae: 0.2043
# Epoch 13/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1690 - mae: 0.1540 - val_loss: 0.3680 - val_mae: 0.2222
# Epoch 14/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1527 - mae: 0.1531 - val_loss: 0.3585 - val_mae: 0.2063
# Epoch 15/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1371 - mae: 0.1466 - val_loss: 0.3123 - val_mae: 0.1979
# Epoch 16/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1271 - mae: 0.1376 - val_loss: 0.3546 - val_mae: 0.1992
# Epoch 17/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1173 - mae: 0.1319 - val_loss: 0.3088 - val_mae: 0.1770
# Epoch 18/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1125 - mae: 0.1264 - val_loss: 0.3258 - val_mae: 0.1905
# Epoch 19/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1434 - mae: 0.1373 - val_loss: 0.3835 - val_mae: 0.1979
# Epoch 20/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2128 - mae: 0.1537 - val_loss: 0.3353 - val_mae: 0.1903
# Epoch 21/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1397 - mae: 0.1363 - val_loss: 0.3288 - val_mae: 0.1822
# Epoch 22/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1225 - mae: 0.1302 - val_loss: 0.3429 - val_mae: 0.1708
# Epoch 23/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1316 - mae: 0.1384 - val_loss: 0.3185 - val_mae: 0.1954
# Epoch 24/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1175 - mae: 0.1318 - val_loss: 0.3137 - val_mae: 0.1750
# Epoch 25/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1020 - mae: 0.1240 - val_loss: 0.3124 - val_mae: 0.1791
# Epoch 26/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1073 - mae: 0.1249 - val_loss: 0.3148 - val_mae: 0.2079
# Epoch 27/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1017 - mae: 0.1306 - val_loss: 0.3079 - val_mae: 0.1718
# Epoch 28/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1159 - mae: 0.1314 - val_loss: 0.2984 - val_mae: 0.1680
# Epoch 29/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1225 - mae: 0.1283 - val_loss: 0.3083 - val_mae: 0.1774
# Epoch 30/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1121 - mae: 0.1250 - val_loss: 0.3307 - val_mae: 0.1902
# Epoch 31/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0856 - mae: 0.1158 - val_loss: 0.3286 - val_mae: 0.1802
# Epoch 32/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0785 - mae: 0.1098 - val_loss: 0.3221 - val_mae: 0.1848
# Epoch 33/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0887 - mae: 0.1139 - val_loss: 0.3312 - val_mae: 0.1735
# Epoch 34/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1174 - mae: 0.1240 - val_loss: 0.3198 - val_mae: 0.1637
# Epoch 35/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0953 - mae: 0.1171 - val_loss: 0.2973 - val_mae: 0.1640
# Epoch 36/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0954 - mae: 0.1169 - val_loss: 0.3060 - val_mae: 0.1747
# Epoch 37/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0814 - mae: 0.1092 - val_loss: 0.3849 - val_mae: 0.1942
# Epoch 38/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1196 - mae: 0.1197 - val_loss: 0.3237 - val_mae: 0.1695
# Epoch 39/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0874 - mae: 0.1152 - val_loss: 0.3303 - val_mae: 0.1883
# Epoch 40/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0768 - mae: 0.1120 - val_loss: 0.3317 - val_mae: 0.1821
# Epoch 41/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0699 - mae: 0.1077 - val_loss: 0.3137 - val_mae: 0.1808
# Epoch 42/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0632 - mae: 0.1041 - val_loss: 0.3106 - val_mae: 0.1892
# Epoch 43/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0650 - mae: 0.1047 - val_loss: 0.3750 - val_mae: 0.1960
# Epoch 44/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0757 - mae: 0.1057 - val_loss: 0.3814 - val_mae: 0.1912
# Epoch 45/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1278 - mae: 0.1205 - val_loss: 0.3353 - val_mae: 0.1781
# Epoch 46/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1015 - mae: 0.1157 - val_loss: 0.2811 - val_mae: 0.1864
# Epoch 47/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0992 - mae: 0.1205 - val_loss: 0.3017 - val_mae: 0.1832
# Epoch 48/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0857 - mae: 0.1129 - val_loss: 0.2795 - val_mae: 0.2051
# Epoch 49/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0854 - mae: 0.1204 - val_loss: 0.3078 - val_mae: 0.2045
# Epoch 50/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0687 - mae: 0.1081 - val_loss: 0.2869 - val_mae: 0.1652
# processing fold # 2
# Epoch 1/50
# 10/10 [==============================] - 3s 85ms/step - loss: 1.0185 - mae: 0.4507 - val_loss: 0.8829 - val_mae: 0.4360
# Epoch 2/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.5887 - mae: 0.3389 - val_loss: 0.8421 - val_mae: 0.3547
# Epoch 3/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.6313 - mae: 0.3062 - val_loss: 0.3942 - val_mae: 0.2539
# Epoch 4/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.3458 - mae: 0.2475 - val_loss: 0.2911 - val_mae: 0.2239
# Epoch 5/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2674 - mae: 0.2190 - val_loss: 0.2631 - val_mae: 0.1989
# Epoch 6/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2073 - mae: 0.1859 - val_loss: 0.3039 - val_mae: 0.1876
# Epoch 7/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1908 - mae: 0.1735 - val_loss: 0.3431 - val_mae: 0.1846
# Epoch 8/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1707 - mae: 0.1631 - val_loss: 0.3075 - val_mae: 0.1748
# Epoch 9/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1609 - mae: 0.1583 - val_loss: 0.2982 - val_mae: 0.1808
# Epoch 10/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1539 - mae: 0.1559 - val_loss: 0.3069 - val_mae: 0.1730
# Epoch 11/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1461 - mae: 0.1530 - val_loss: 0.3125 - val_mae: 0.1732
# Epoch 12/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1270 - mae: 0.1434 - val_loss: 0.3013 - val_mae: 0.1678
# Epoch 13/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1214 - mae: 0.1434 - val_loss: 0.3051 - val_mae: 0.1801
# Epoch 14/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1159 - mae: 0.1437 - val_loss: 0.2885 - val_mae: 0.1647
# Epoch 15/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0989 - mae: 0.1361 - val_loss: 0.2697 - val_mae: 0.1733
# Epoch 16/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0921 - mae: 0.1307 - val_loss: 0.2862 - val_mae: 0.1666
# Epoch 17/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0853 - mae: 0.1269 - val_loss: 0.2729 - val_mae: 0.1582
# Epoch 18/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0998 - mae: 0.1273 - val_loss: 0.2687 - val_mae: 0.1697
# Epoch 19/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0900 - mae: 0.1257 - val_loss: 0.2722 - val_mae: 0.1550
# Epoch 20/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0940 - mae: 0.1250 - val_loss: 0.2885 - val_mae: 0.1614
# Epoch 21/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0809 - mae: 0.1190 - val_loss: 0.2747 - val_mae: 0.1761
# Epoch 22/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0913 - mae: 0.1224 - val_loss: 0.2841 - val_mae: 0.1801
# Epoch 23/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0889 - mae: 0.1194 - val_loss: 0.2933 - val_mae: 0.1702
# Epoch 24/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1012 - mae: 0.1238 - val_loss: 0.3240 - val_mae: 0.1654
# Epoch 25/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0867 - mae: 0.1199 - val_loss: 0.2600 - val_mae: 0.1684
# Epoch 26/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0746 - mae: 0.1167 - val_loss: 0.3191 - val_mae: 0.1672
# Epoch 27/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0792 - mae: 0.1167 - val_loss: 0.2886 - val_mae: 0.1639
# Epoch 28/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0730 - mae: 0.1141 - val_loss: 0.3031 - val_mae: 0.1660
# Epoch 29/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0764 - mae: 0.1133 - val_loss: 0.3088 - val_mae: 0.1699
# Epoch 30/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1353 - mae: 0.1261 - val_loss: 0.3063 - val_mae: 0.1728
# Epoch 31/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0975 - mae: 0.1238 - val_loss: 0.2781 - val_mae: 0.1766
# Epoch 32/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0797 - mae: 0.1168 - val_loss: 0.2823 - val_mae: 0.1910
# Epoch 33/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0779 - mae: 0.1175 - val_loss: 0.3024 - val_mae: 0.1836
# Epoch 34/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0699 - mae: 0.1126 - val_loss: 0.3833 - val_mae: 0.1895
# Epoch 35/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.2860 - mae: 0.1557 - val_loss: 0.3341 - val_mae: 0.1810
# Epoch 36/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1525 - mae: 0.1376 - val_loss: 0.3430 - val_mae: 0.1894
# Epoch 37/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1553 - mae: 0.1420 - val_loss: 0.3069 - val_mae: 0.1786
# Epoch 38/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1282 - mae: 0.1385 - val_loss: 0.3032 - val_mae: 0.1994
# Epoch 39/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.1819 - mae: 0.1464 - val_loss: 0.3410 - val_mae: 0.2064
# Epoch 40/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1151 - mae: 0.1352 - val_loss: 0.3162 - val_mae: 0.1652
# Epoch 41/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1013 - mae: 0.1334 - val_loss: 0.3127 - val_mae: 0.1842
# Epoch 42/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0849 - mae: 0.1242 - val_loss: 0.3331 - val_mae: 0.1900
# Epoch 43/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0957 - mae: 0.1226 - val_loss: 0.3185 - val_mae: 0.1671
# Epoch 44/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0854 - mae: 0.1200 - val_loss: 0.3292 - val_mae: 0.1998
# Epoch 45/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0819 - mae: 0.1185 - val_loss: 0.3197 - val_mae: 0.2019
# Epoch 46/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0817 - mae: 0.1200 - val_loss: 0.3149 - val_mae: 0.1731
# Epoch 47/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0662 - mae: 0.1107 - val_loss: 0.3253 - val_mae: 0.1726
# Epoch 48/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0606 - mae: 0.1058 - val_loss: 0.3290 - val_mae: 0.1734
# Epoch 49/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0714 - mae: 0.1093 - val_loss: 0.3015 - val_mae: 0.1623
# Epoch 50/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0612 - mae: 0.1081 - val_loss: 0.3086 - val_mae: 0.1635
# processing fold # 3
# Epoch 1/50
# 10/10 [==============================] - 3s 81ms/step - loss: 1.0821 - mae: 0.4428 - val_loss: 1.1595 - val_mae: 0.7334
# Epoch 2/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9168 - mae: 0.3938 - val_loss: 0.6527 - val_mae: 0.3793
# Epoch 3/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.4511 - mae: 0.2893 - val_loss: 0.4384 - val_mae: 0.2638
# Epoch 4/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3480 - mae: 0.2538 - val_loss: 0.3517 - val_mae: 0.2495
# Epoch 5/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2514 - mae: 0.2139 - val_loss: 0.3386 - val_mae: 0.2104
# Epoch 6/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2132 - mae: 0.1889 - val_loss: 0.3255 - val_mae: 0.1893
# Epoch 7/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1753 - mae: 0.1665 - val_loss: 0.3271 - val_mae: 0.1902
# Epoch 8/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1757 - mae: 0.1612 - val_loss: 0.4366 - val_mae: 0.2020
# Epoch 9/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1867 - mae: 0.1619 - val_loss: 0.3555 - val_mae: 0.1796
# Epoch 10/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1803 - mae: 0.1568 - val_loss: 0.3584 - val_mae: 0.1856
# Epoch 11/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1455 - mae: 0.1471 - val_loss: 0.3326 - val_mae: 0.1739
# Epoch 12/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2071 - mae: 0.1602 - val_loss: 0.2977 - val_mae: 0.1746
# Epoch 13/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1553 - mae: 0.1468 - val_loss: 0.3539 - val_mae: 0.2025
# Epoch 14/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1950 - mae: 0.1611 - val_loss: 0.3744 - val_mae: 0.2014
# Epoch 15/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1716 - mae: 0.1545 - val_loss: 0.3063 - val_mae: 0.1840
# Epoch 16/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1603 - mae: 0.1515 - val_loss: 0.2780 - val_mae: 0.1756
# Epoch 17/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1374 - mae: 0.1485 - val_loss: 0.2984 - val_mae: 0.1752
# Epoch 18/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1249 - mae: 0.1392 - val_loss: 0.3221 - val_mae: 0.1875
# Epoch 19/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1151 - mae: 0.1394 - val_loss: 0.3283 - val_mae: 0.1799
# Epoch 20/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1114 - mae: 0.1344 - val_loss: 0.3233 - val_mae: 0.1860
# Epoch 21/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1012 - mae: 0.1307 - val_loss: 0.3603 - val_mae: 0.1851
# Epoch 22/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1168 - mae: 0.1339 - val_loss: 0.3376 - val_mae: 0.1944
# Epoch 23/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1257 - mae: 0.1363 - val_loss: 0.3934 - val_mae: 0.2173
# Epoch 24/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1093 - mae: 0.1333 - val_loss: 0.3931 - val_mae: 0.2014
# Epoch 25/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1329 - mae: 0.1355 - val_loss: 0.4003 - val_mae: 0.2061
# Epoch 26/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1054 - mae: 0.1299 - val_loss: 0.2855 - val_mae: 0.1789
# Epoch 27/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0877 - mae: 0.1229 - val_loss: 0.2988 - val_mae: 0.1740
# Epoch 28/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0891 - mae: 0.1196 - val_loss: 0.3174 - val_mae: 0.1925
# Epoch 29/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0817 - mae: 0.1188 - val_loss: 0.2952 - val_mae: 0.1776
# Epoch 30/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0772 - mae: 0.1175 - val_loss: 0.3179 - val_mae: 0.2014
# Epoch 31/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0796 - mae: 0.1153 - val_loss: 0.3402 - val_mae: 0.1935
# Epoch 32/50
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1725 - mae: 0.1313 - val_loss: 0.3106 - val_mae: 0.1885
# Epoch 33/50
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1111 - mae: 0.1246 - val_loss: 0.3080 - val_mae: 0.1893
# Epoch 34/50
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0945 - mae: 0.1177 - val_loss: 0.2983 - val_mae: 0.1961
# Epoch 35/50
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0818 - mae: 0.1145 - val_loss: 0.3127 - val_mae: 0.1811
# Epoch 36/50
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0986 - mae: 0.1182 - val_loss: 0.2904 - val_mae: 0.1901
# Epoch 37/50
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1846 - mae: 0.1458 - val_loss: 0.4902 - val_mae: 0.2662
# Epoch 38/50
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1696 - mae: 0.1447 - val_loss: 0.2971 - val_mae: 0.2118
# Epoch 39/50
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1057 - mae: 0.1262 - val_loss: 0.2924 - val_mae: 0.2053
# Epoch 40/50
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0990 - mae: 0.1262 - val_loss: 0.3237 - val_mae: 0.2131
# Epoch 41/50
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0739 - mae: 0.1161 - val_loss: 0.3162 - val_mae: 0.2172
# Epoch 42/50
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0699 - mae: 0.1115 - val_loss: 0.2777 - val_mae: 0.1969
# Epoch 43/50
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0597 - mae: 0.1068 - val_loss: 0.2973 - val_mae: 0.2031
# Epoch 44/50
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0524 - mae: 0.1022 - val_loss: 0.2818 - val_mae: 0.1989
# Epoch 45/50
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0556 - mae: 0.1020 - val_loss: 0.2880 - val_mae: 0.2083
# Epoch 46/50
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0563 - mae: 0.1040 - val_loss: 0.2938 - val_mae: 0.2064
# Epoch 47/50
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0531 - mae: 0.1000 - val_loss: 0.2920 - val_mae: 0.1883
# Epoch 48/50
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0456 - mae: 0.0982 - val_loss: 0.2956 - val_mae: 0.2173
# Epoch 49/50
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0477 - mae: 0.0969 - val_loss: 0.2823 - val_mae: 0.2007
# Epoch 50/50
# 10/10 [==============================] - 0s 45ms/step - loss: 0.0459 - mae: 0.0960 - val_loss: 0.2847 - val_mae: 0.2080
# processing fold # 4
# Epoch 1/50
# 10/10 [==============================] - 5s 86ms/step - loss: 1.0819 - mae: 0.4741 - val_loss: 1.0291 - val_mae: 0.4544
# Epoch 2/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9059 - mae: 0.4436 - val_loss: 0.7710 - val_mae: 0.3475
# Epoch 3/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.5642 - mae: 0.3297 - val_loss: 0.5701 - val_mae: 0.2886
# Epoch 4/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.4211 - mae: 0.2685 - val_loss: 0.4238 - val_mae: 0.2557
# Epoch 5/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2901 - mae: 0.2257 - val_loss: 0.3638 - val_mae: 0.2164
# Epoch 6/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2052 - mae: 0.1847 - val_loss: 0.3291 - val_mae: 0.1859
# Epoch 7/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1940 - mae: 0.1702 - val_loss: 0.3973 - val_mae: 0.1873
# Epoch 8/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2048 - mae: 0.1695 - val_loss: 0.3620 - val_mae: 0.1889
# Epoch 9/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1950 - mae: 0.1629 - val_loss: 0.3847 - val_mae: 0.1967
# Epoch 10/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2496 - mae: 0.1731 - val_loss: 0.3476 - val_mae: 0.1795
# Epoch 11/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1750 - mae: 0.1582 - val_loss: 0.3613 - val_mae: 0.1805
# Epoch 12/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1579 - mae: 0.1512 - val_loss: 0.3512 - val_mae: 0.1802
# Epoch 13/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1474 - mae: 0.1462 - val_loss: 0.3428 - val_mae: 0.1783
# Epoch 14/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1189 - mae: 0.1375 - val_loss: 0.3286 - val_mae: 0.1748
# Epoch 15/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1251 - mae: 0.1375 - val_loss: 0.3278 - val_mae: 0.1909
# Epoch 16/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1234 - mae: 0.1402 - val_loss: 0.3732 - val_mae: 0.1807
# Epoch 17/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1080 - mae: 0.1325 - val_loss: 0.3796 - val_mae: 0.1810
# Epoch 18/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1190 - mae: 0.1344 - val_loss: 0.3500 - val_mae: 0.1825
# Epoch 19/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0977 - mae: 0.1285 - val_loss: 0.3326 - val_mae: 0.1822
# Epoch 20/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0884 - mae: 0.1250 - val_loss: 0.3376 - val_mae: 0.1813
# Epoch 21/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0889 - mae: 0.1221 - val_loss: 0.3428 - val_mae: 0.1738
# Epoch 22/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0804 - mae: 0.1171 - val_loss: 0.3480 - val_mae: 0.1787
# Epoch 23/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0846 - mae: 0.1173 - val_loss: 0.3684 - val_mae: 0.1861
# Epoch 24/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0647 - mae: 0.1108 - val_loss: 0.3833 - val_mae: 0.1808
# Epoch 25/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0960 - mae: 0.1183 - val_loss: 0.3385 - val_mae: 0.1735
# Epoch 26/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0992 - mae: 0.1215 - val_loss: 0.3358 - val_mae: 0.1830
# Epoch 27/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0935 - mae: 0.1225 - val_loss: 0.3634 - val_mae: 0.1860
# Epoch 28/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0888 - mae: 0.1205 - val_loss: 0.3185 - val_mae: 0.1860
# Epoch 29/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0827 - mae: 0.1176 - val_loss: 0.3185 - val_mae: 0.1791
# Epoch 30/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0740 - mae: 0.1119 - val_loss: 0.3174 - val_mae: 0.1744
# Epoch 31/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0639 - mae: 0.1066 - val_loss: 0.3356 - val_mae: 0.1768
# Epoch 32/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0604 - mae: 0.1049 - val_loss: 0.3114 - val_mae: 0.1696
# Epoch 33/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0671 - mae: 0.1055 - val_loss: 0.3947 - val_mae: 0.1906
# Epoch 34/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0881 - mae: 0.1138 - val_loss: 0.4635 - val_mae: 0.1996
# Epoch 35/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1194 - mae: 0.1232 - val_loss: 0.3688 - val_mae: 0.1832
# Epoch 36/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0822 - mae: 0.1115 - val_loss: 0.3121 - val_mae: 0.1690
# Epoch 37/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0822 - mae: 0.1116 - val_loss: 0.3521 - val_mae: 0.1703
# Epoch 38/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0913 - mae: 0.1140 - val_loss: 0.3164 - val_mae: 0.1709
# Epoch 39/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0831 - mae: 0.1173 - val_loss: 0.3191 - val_mae: 0.1684
# Epoch 40/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0722 - mae: 0.1092 - val_loss: 0.3176 - val_mae: 0.1722
# Epoch 41/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0745 - mae: 0.1095 - val_loss: 0.3326 - val_mae: 0.1754
# Epoch 42/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1335 - mae: 0.1218 - val_loss: 0.3278 - val_mae: 0.1776
# Epoch 43/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1212 - mae: 0.1238 - val_loss: 0.3110 - val_mae: 0.1877
# Epoch 44/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0833 - mae: 0.1201 - val_loss: 0.2848 - val_mae: 0.1656
# Epoch 45/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0705 - mae: 0.1143 - val_loss: 0.2787 - val_mae: 0.1719
# Epoch 46/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0643 - mae: 0.1064 - val_loss: 0.2873 - val_mae: 0.1946
# Epoch 47/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0898 - mae: 0.1209 - val_loss: 0.3197 - val_mae: 0.1740
# Epoch 48/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0824 - mae: 0.1122 - val_loss: 0.2852 - val_mae: 0.1665
# Epoch 49/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0855 - mae: 0.1129 - val_loss: 0.2755 - val_mae: 0.1660
# Epoch 50/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0776 - mae: 0.1113 - val_loss: 0.2617 - val_mae: 0.1644

# %%
# Calculate the average accuracy acorss validations.
average_train_history = [
    np.mean([x[i] for x in  all_train_histories]) for i in range(num_epochs)]

average_val_history = [
    np.mean([x[i] for x in all_val_histories]) for i in range(num_epochs)]

# %%
# Define a function to smooth the history of loss.
def smooth_curve(points, factor=0.9):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)
  return smoothed_points

# %%
smooth_history1 = smooth_curve(average_train_history)
smooth_history2 = smooth_curve(average_val_history)

# Plot the smmoothed history.
plt.plot(range(1, len(smooth_history1) + 1), smooth_history1, label = 'training')
plt.plot(range(1, len(smooth_history2) + 1), smooth_history2, label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Purse Regression Model Loss")
plt.legend()
plt.savefig('NN_loss_purse.png')
plt.show()

# %%
train_data = create_data(x_train)
test_data = create_data(x_test)

# Train the final model.
model = build_model(cat_col, cat_col_name, embedding_dim)
model.fit(
    train_data,
    {"prediction": y_train[:, -1]},
    epochs=50,
    batch_size=1000)

# Print out the final results.
model.evaluate(train_data, y_train[:, -1])
model.evaluate(test_data, y_test[:, -1])
# Out:
# Epoch 1/50
# 13/13 [==============================] - 3s 16ms/step - loss: 1.0296 - mae: 0.4798
# Epoch 2/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.6720 - mae: 0.3537
# Epoch 3/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4033 - mae: 0.2765
# Epoch 4/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2676 - mae: 0.2181
# Epoch 5/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2199 - mae: 0.1860
# Epoch 6/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1840 - mae: 0.1683
# Epoch 7/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1757 - mae: 0.1593
# Epoch 8/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.1984 - mae: 0.1630
# Epoch 9/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2063 - mae: 0.1646
# Epoch 10/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2225 - mae: 0.1669
# Epoch 11/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1553 - mae: 0.1567
# Epoch 12/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.1591 - mae: 0.1511
# Epoch 13/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1420 - mae: 0.1467
# Epoch 14/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1693 - mae: 0.1502
# Epoch 15/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1740 - mae: 0.1497
# Epoch 16/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1551 - mae: 0.1443
# Epoch 17/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1445 - mae: 0.1414
# Epoch 18/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.1070 - mae: 0.1294
# Epoch 19/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0943 - mae: 0.1233
# Epoch 20/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0831 - mae: 0.1210
# Epoch 21/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0804 - mae: 0.1178
# Epoch 22/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0861 - mae: 0.1174
# Epoch 23/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0861 - mae: 0.1181
# Epoch 24/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0834 - mae: 0.1171
# Epoch 25/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0852 - mae: 0.1167
# Epoch 26/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0732 - mae: 0.1133
# Epoch 27/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0651 - mae: 0.1139
# Epoch 28/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0746 - mae: 0.1186
# Epoch 29/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0742 - mae: 0.1146
# Epoch 30/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0738 - mae: 0.1113
# Epoch 31/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0664 - mae: 0.1092
# Epoch 32/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0580 - mae: 0.1042
# Epoch 33/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0543 - mae: 0.1015
# Epoch 34/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0662 - mae: 0.1060
# Epoch 35/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0637 - mae: 0.1065
# Epoch 36/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0625 - mae: 0.1067
# Epoch 37/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0649 - mae: 0.1055
# Epoch 38/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0597 - mae: 0.1059
# Epoch 39/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0569 - mae: 0.1113
# Epoch 40/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0597 - mae: 0.1051
# Epoch 41/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0957 - mae: 0.1125
# Epoch 42/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0711 - mae: 0.1082
# Epoch 43/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0717 - mae: 0.1095
# Epoch 44/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0715 - mae: 0.1052
# Epoch 45/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0656 - mae: 0.1067
# Epoch 46/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0651 - mae: 0.1065
# Epoch 47/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0524 - mae: 0.1061
# Epoch 48/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0587 - mae: 0.1054
# Epoch 49/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0606 - mae: 0.1035
# Epoch 50/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0529 - mae: 0.0998
# 377/377 [==============================] - 2s 4ms/step - loss: 0.0598 - mae: 0.1259
# 95/95 [==============================] - 1s 4ms/step - loss: 0.2560 - mae: 0.1726
# [0.2560358941555023, 0.17261260747909546]
