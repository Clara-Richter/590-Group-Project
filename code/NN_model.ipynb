# %%
# !pip install wordninja
# !pip install num2words

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing
import wordninja
from nltk.tokenize import RegexpTokenizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import re
import num2words
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

pd.set_option('display.max_columns', None)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordninja in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: num2words in /usr/local/lib/python3.7/dist-packages (0.5.12)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words) (0.6.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Specify the path to our shared drive. Should work for all of us.
path = '/content/drive/Shareddrives/ANLY590_GROUP_4_PROJECT'

# %%
df = pd.read_csv(path + "/data/merged_data/joined_data_without_position.csv", index_col=0)

# %% [markdown]
# ## Preprocessing

# %%
# Create win dummy variable.
df['win'] = np.where(df['race_number'] >= 3, 1, 0)

# Drop the redundant variables.
df = df.drop(['position_at_finish', 'post_time', 'distance_id'], axis = 1)

# Convert the race number as string.
df['race_number'] = df['race_number'].astype('str')

# Convert to float and fill NA
df['day_since_last_race'] = df['day_since_last_race'].apply(lambda x : x[:-5] if x is not np.nan else np.nan).astype('float').fillna(0)

# Fill the comments column with string None.
df['Comments'] = df['Comments'].fillna('None')

# %%
# Preprocess the comments. 
res = []
tokenizer = RegexpTokenizer(r'\w+')
for i in df.Comments:
  if type(i) == str:
    re.sub(r"(\d+)", lambda x: num2words.num2words(int(x.group(0))), i)
    phrase_list = tokenizer.tokenize(i)
    splited_tokens = [wordninja.split(i) for i in phrase_list]
    flat_splited_tokens = [j for sublist in splited_tokens for j in sublist]
    res.append(flat_splited_tokens)    
  else:
    res.append(np.nan)

df['Comments'] = res

# %%
# Convert all numerical columns to float.
for i in df.columns:
  if df[i].dtype == int:
    df[i] = df[i].astype('float')

# %% [markdown]
# Here I concat all three outcome variables, so when training, be mindful about the column index

# %%
# Separate the target data and others.
target = df[['win', 'odds', 'purse']]
data = df.drop(['win', 'odds', 'purse','Comments'], axis = 1)

# %%
# Separate the training data to numericals, categoricals and the text.
cat_col = []
num_col = []

for i in data.columns:
  if data[i].dtype == object:
    cat_col.append((i, data.columns.get_loc(i)))

  elif data[i].dtype == float:
    num_col.append((i, data.columns.get_loc(i)))

# %%
# Label encode the categorical variables and standarlize the numericals. 
for i in cat_col:
  le = preprocessing.LabelEncoder()
  data[i[0]] = le.fit_transform(data[i[0]])

num_col_name = [j[0] for j in num_col]
cat_col_name = [j[0] for j in cat_col]

se = preprocessing.StandardScaler()
data[num_col_name] = se.fit_transform(data[num_col_name])

se = preprocessing.StandardScaler()
target[['odds', 'purse']] = se.fit_transform(target[['odds', 'purse']])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
# Create a dict for the unique categories and the desired embedding dimensions for each categorical variable. 
# Jeremy Howard provides the following rule of thumb; embedding size = min(50, number of categories/2).
def create_embedding_dim():

  embedding_dim = {}
  for i in range(len(cat_col)):
    embedding_dim[cat_col[i][0]] = (data[cat_col[i][0]].nunique(), min(50, data[cat_col[i][0]].nunique() //2 ))

  return embedding_dim

# %%
embedding_dim = create_embedding_dim()

# %%
# Convert the comments column to tokes and pad each sequence.

max_words = 1100 # The length of the vocabulary.

# Make the units matrices.
tokenizer = Tokenizer(max_words)
tokenizer.fit_on_texts(df['Comments'])
data_text = tokenizer.texts_to_sequences(df['Comments'])

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# Maximum length for a vector.
maxlen = 15

# Pad the sequence.
data_text = pad_sequences(data_text, maxlen=maxlen)

print('Shape of data tensor:', data_text.shape)
# Out:
# Found 1133 unique tokens.
# Shape of data tensor: (15081, 15)

# %%
# Concat the regular features with text features. Transform them all to numpy array.
data = np.concatenate((np.asarray(data), data_text), axis=1)
target = np.asarray(target)

# %% [markdown]
# ## Modeling

# %% [markdown]
# Here I build the model mainly with a class and Keras functional API for it will allow us to build a more flexible model.

# %%
class NN():

    def __init__(self, cat_col, cat_col_name, embedding_dim):
      # For each categorical variable, we need to specify a input layer and a embedding layer. So I created them all by iteratively specifying them as attributes.
      for i in cat_col_name:

        # These are all the input layers for the cat_col
        setattr(self, i + '_input', keras.Input(shape=(1,), name=i))

        #Then we embed them by the dimensions we created earlier.
        setattr(self, i + '_embedding', layers.Embedding(embedding_dim[i][0], embedding_dim[i][1], input_length = 1)(getattr(self, i + '_input')))

        # Next we rehsape them so that they can be concatenated with other layers' output.
        setattr(self, i + '_reshape', layers.Reshape(target_shape=(embedding_dim[i][1], ))(getattr(self, i + '_embedding')))

      # Input for the numerical variables.
      setattr(self, 'num_input', keras.Input(shape=(11,), name = 'num_col'))
      setattr(self, 'num_features', layers.Dense(64, activation='relu')(getattr(self, 'num_input')))

      # Input and embedding layers for the texts variable.
      setattr(self, 'text_input', keras.Input(shape=(None,), name = 'text'))
      setattr(self, 'text_embedding', layers.Embedding(1000, 64)(getattr(self, 'text_input')))

    def concat(self):

      # LSTM layer for the text data.
      text_features = layers.LSTM(128)(getattr(self, 'text_embedding'))
      
      # Reshape the text output so that the outputs can be concatenated
      text_features = layers.Reshape(target_shape=(128, ))(text_features)

      # Concatenate all outputs from previous layers.
      x = layers.concatenate([getattr(self, i + '_reshape') for i in cat_col_name] + [getattr(self, 'num_features')] + [text_features])

      # More dense layers.
      x = layers.Dense(128, name="dense1")(x)
      x = layers.Dense(128, name="dense2")(x)
      pred = layers.Dense(1,  name="prediction")(x)

      # Compiling the model by specifying the inputs and outputs.
      model = keras.Model(
      inputs=[getattr(self, i + '_input') for i in cat_col_name] + [getattr(self, 'num_input')] + [getattr(self, 'text_input')],
      outputs=[pred])

      return model

# %% [markdown]
# For different outcome variables, we can just change the layer that generate the prediction, the loss and the metric.

# %% [markdown]
# For hyperparameter tuning, I think apart from changing the regular ones, we can also all more layers. Maybe some dense layer after the categorical embedding layer.

# %%
def build_model(cat_col, cat_col_name, embedding_dim):

  # Instantiate the model.
  model = NN(cat_col, cat_col_name, embedding_dim)
  model = model.concat()

  model.compile(
    optimizer=keras.optimizers.RMSprop(1e-3),
    loss={
        #"prediction": keras.losses.BinaryCrossentropy(from_logits=True)
        "prediction": keras.losses.mean_squared_error 
    },
    metrics=['mae']
    #metrics=['acc']
)
  return model

# %%
# Instantiate the model.
model = build_model(cat_col, cat_col_name, embedding_dim)

# %%
# Check the dimensions and the graph of layers.
model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text (InputLayer)              [(None, None)]       0           []
#
#  track_id (InputLayer)          [(None, 1)]          0           []
#
#  race_date (InputLayer)         [(None, 1)]          0           []
#
#  race_number (InputLayer)       [(None, 1)]          0           []
#
#  program_number (InputLayer)    [(None, 1)]          0           []
#
#  jockey (InputLayer)            [(None, 1)]          0           []
#
#  course_type (InputLayer)       [(None, 1)]          0           []
#
#  track_condition (InputLayer)   [(None, 1)]          0           []
#
#  race_type (InputLayer)         [(None, 1)]          0           []
#
#  last_race_track (InputLayer)   [(None, 1)]          0           []
#
#  weathertype (InputLayer)       [(None, 1)]          0           []
#
#  embedding_10 (Embedding)       (None, None, 64)     64000       ['text[0][0]']
#
#  embedding (Embedding)          (None, 1, 1)         3           ['track_id[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 50)        10850       ['race_date[0][0]']
#
#  embedding_2 (Embedding)        (None, 1, 6)         78          ['race_number[0][0]']
#
#  embedding_3 (Embedding)        (None, 1, 10)        200         ['program_number[0][0]']
#
#  embedding_4 (Embedding)        (None, 1, 50)        8900        ['jockey[0][0]']
#
#  embedding_5 (Embedding)        (None, 1, 2)         10          ['course_type[0][0]']
#
#  embedding_6 (Embedding)        (None, 1, 3)         21          ['track_condition[0][0]']
#
#  embedding_7 (Embedding)        (None, 1, 6)         72          ['race_type[0][0]']
#
#  embedding_8 (Embedding)        (None, 1, 50)        9150        ['last_race_track[0][0]']
#
#  embedding_9 (Embedding)        (None, 1, 25)        1275        ['weathertype[0][0]']
#
#  num_col (InputLayer)           [(None, 11)]         0           []
#
#  lstm (LSTM)                    (None, 128)          98816       ['embedding_10[0][0]']
#
#  reshape (Reshape)              (None, 1)            0           ['embedding[0][0]']
#
#  reshape_1 (Reshape)            (None, 50)           0           ['embedding_1[0][0]']
#
#  reshape_2 (Reshape)            (None, 6)            0           ['embedding_2[0][0]']
#
#  reshape_3 (Reshape)            (None, 10)           0           ['embedding_3[0][0]']
#
#  reshape_4 (Reshape)            (None, 50)           0           ['embedding_4[0][0]']
#
#  reshape_5 (Reshape)            (None, 2)            0           ['embedding_5[0][0]']
#
#  reshape_6 (Reshape)            (None, 3)            0           ['embedding_6[0][0]']
#
#  reshape_7 (Reshape)            (None, 6)            0           ['embedding_7[0][0]']
#
#  reshape_8 (Reshape)            (None, 50)           0           ['embedding_8[0][0]']
#
#  reshape_9 (Reshape)            (None, 25)           0           ['embedding_9[0][0]']
#
#  dense (Dense)                  (None, 64)           768         ['num_col[0][0]']
#
#  reshape_10 (Reshape)           (None, 128)          0           ['lstm[0][0]']
#
#  concatenate (Concatenate)      (None, 395)          0           ['reshape[0][0]',
#                                                                   'reshape_1[0][0]',
#                                                                   'reshape_2[0][0]',
#                                                                   'reshape_3[0][0]',
#                                                                   'reshape_4[0][0]',
#                                                                   'reshape_5[0][0]',
#                                                                   'reshape_6[0][0]',
#                                                                   'reshape_7[0][0]',
#                                                                   'reshape_8[0][0]',
#                                                                   'reshape_9[0][0]',
#                                                                   'dense[0][0]',
#                                                                   'reshape_10[0][0]']
#
#  dense1 (Dense)                 (None, 128)          50688       ['concatenate[0][0]']
#
#  dense2 (Dense)                 (None, 128)          16512       ['dense1[0][0]']
#
#  prediction (Dense)             (None, 1)            129         ['dense2[0][0]']
#
# ==================================================================================================
# Total params: 261,472
# Trainable params: 261,472
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# This function aims to turn the whole data numpy array to the form that the model can take.
def create_data(whole_data):

  output = {}
  for i in cat_col:
    output[i[0]] = whole_data[:,i[1]]
  output['num_col'] = whole_data[:,[j[1] for j in num_col]]
  output['text'] = whole_data[:, -15:]

  return output

# %%
# Here I did a 4-fold cross validation and log the loss and metric.
# Split the data.
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=1)

# Specify the hyperparameters.
k=4
num_val_samples = len(x_train) // k 
num_epochs = 50
batch_size = 1000
all_train_histories = [] 
all_val_histories = []


for i in range(k):
    print('processing fold #', i + 1)
    
    # Create the validation data and recreate the training data.
    val_data_temp = x_train[i * num_val_samples: (i + 1) * num_val_samples] 
    val_targets_temp = y_train[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate( [x_train[:i * num_val_samples],
        x_train[(i + 1) * num_val_samples:]], axis=0)
    partial_train_targets = np.concatenate( [y_train[:i * num_val_samples],
        y_train[(i + 1) * num_val_samples:]], axis=0)

    #Create the model and train.
    model = build_model(cat_col, cat_col_name, embedding_dim)

    # Create the model usable data inputs.
    train_data = create_data(partial_train_data)
    val_data = create_data(val_data_temp)

    # Train the model.
    history = model.fit(
    train_data,
    {"prediction": partial_train_targets[:, -1]},
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data=(val_data, val_targets_temp[:, -1])
)
    
    # Log the loss
    train_history = history.history['mae']
    val_history = history.history['val_mae']
    all_train_histories.append(train_history)
    all_val_histories.append(val_history)
# Out:
# processing fold # 1
# Epoch 1/50
# 10/10 [==============================] - 5s 85ms/step - loss: 1.0414 - mae: 0.4860 - val_loss: 0.8754 - val_mae: 0.4350
# Epoch 2/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.8233 - mae: 0.4528 - val_loss: 0.7794 - val_mae: 0.3717
# Epoch 3/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.6863 - mae: 0.4360 - val_loss: 0.6311 - val_mae: 0.3552
# Epoch 4/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5295 - mae: 0.3571 - val_loss: 0.8056 - val_mae: 0.6313
# Epoch 5/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.5542 - mae: 0.4241 - val_loss: 0.5211 - val_mae: 0.3724
# Epoch 6/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5026 - mae: 0.4076 - val_loss: 0.5238 - val_mae: 0.3374
# Epoch 7/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4700 - mae: 0.3777 - val_loss: 0.5401 - val_mae: 0.3361
# Epoch 8/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4212 - mae: 0.3191 - val_loss: 0.5213 - val_mae: 0.3451
# Epoch 9/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4835 - mae: 0.3871 - val_loss: 0.5238 - val_mae: 0.4155
# Epoch 10/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4147 - mae: 0.3616 - val_loss: 0.4554 - val_mae: 0.3207
# Epoch 11/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4206 - mae: 0.3564 - val_loss: 0.5102 - val_mae: 0.4247
# Epoch 12/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3918 - mae: 0.3359 - val_loss: 0.5271 - val_mae: 0.4083
# Epoch 13/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4150 - mae: 0.3594 - val_loss: 0.5311 - val_mae: 0.4444
# Epoch 14/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3821 - mae: 0.3225 - val_loss: 0.9980 - val_mae: 0.6451
# Epoch 15/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4488 - mae: 0.3960 - val_loss: 0.4421 - val_mae: 0.3548
# Epoch 16/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.3750 - mae: 0.3327 - val_loss: 0.4520 - val_mae: 0.3544
# Epoch 17/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3574 - mae: 0.3105 - val_loss: 0.4391 - val_mae: 0.3107
# Epoch 18/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3930 - mae: 0.3540 - val_loss: 0.4434 - val_mae: 0.3221
# Epoch 19/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3552 - mae: 0.3090 - val_loss: 0.7551 - val_mae: 0.5357
# Epoch 20/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4073 - mae: 0.3719 - val_loss: 0.4183 - val_mae: 0.3483
# Epoch 21/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.3450 - mae: 0.3140 - val_loss: 0.4707 - val_mae: 0.4014
# Epoch 22/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3804 - mae: 0.3636 - val_loss: 0.4479 - val_mae: 0.3775
# Epoch 23/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3520 - mae: 0.3130 - val_loss: 0.4738 - val_mae: 0.3904
# Epoch 24/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3607 - mae: 0.3401 - val_loss: 0.4594 - val_mae: 0.3784
# Epoch 25/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3652 - mae: 0.3530 - val_loss: 0.4482 - val_mae: 0.2997
# Epoch 26/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3410 - mae: 0.3047 - val_loss: 0.4398 - val_mae: 0.3608
# Epoch 27/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3538 - mae: 0.3349 - val_loss: 0.4441 - val_mae: 0.3270
# Epoch 28/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3392 - mae: 0.3089 - val_loss: 0.5460 - val_mae: 0.4670
# Epoch 29/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3618 - mae: 0.3598 - val_loss: 0.4996 - val_mae: 0.4128
# Epoch 30/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3382 - mae: 0.3375 - val_loss: 0.4522 - val_mae: 0.3683
# Epoch 31/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3428 - mae: 0.3281 - val_loss: 0.4456 - val_mae: 0.3470
# Epoch 32/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3371 - mae: 0.3177 - val_loss: 0.4338 - val_mae: 0.3604
# Epoch 33/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3397 - mae: 0.3173 - val_loss: 0.4984 - val_mae: 0.4630
# Epoch 34/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.3462 - mae: 0.3392 - val_loss: 0.4251 - val_mae: 0.3675
# Epoch 35/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3375 - mae: 0.3370 - val_loss: 0.4204 - val_mae: 0.3225
# Epoch 36/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3236 - mae: 0.3055 - val_loss: 0.5277 - val_mae: 0.4626
# Epoch 37/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3414 - mae: 0.3319 - val_loss: 0.4118 - val_mae: 0.3323
# Epoch 38/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3155 - mae: 0.2979 - val_loss: 0.7092 - val_mae: 0.5609
# Epoch 39/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.3658 - mae: 0.3527 - val_loss: 0.4136 - val_mae: 0.3386
# Epoch 40/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3100 - mae: 0.3041 - val_loss: 0.4930 - val_mae: 0.4284
# Epoch 41/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3181 - mae: 0.3082 - val_loss: 0.7000 - val_mae: 0.5378
# Epoch 42/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3599 - mae: 0.3514 - val_loss: 0.4139 - val_mae: 0.3247
# Epoch 43/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3130 - mae: 0.2999 - val_loss: 0.4167 - val_mae: 0.3189
# Epoch 44/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.3272 - mae: 0.3147 - val_loss: 0.4111 - val_mae: 0.3525
# Epoch 45/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.3137 - mae: 0.3108 - val_loss: 0.4919 - val_mae: 0.4193
# Epoch 46/50
# 10/10 [==============================] - 0s 30ms/step - loss: 0.3232 - mae: 0.3309 - val_loss: 0.4481 - val_mae: 0.3027
# Epoch 47/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.3140 - mae: 0.2855 - val_loss: 0.5267 - val_mae: 0.4581
# Epoch 48/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3266 - mae: 0.3307 - val_loss: 0.4206 - val_mae: 0.3237
# Epoch 49/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.3147 - mae: 0.3085 - val_loss: 0.4425 - val_mae: 0.3585
# Epoch 50/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3186 - mae: 0.3127 - val_loss: 0.4172 - val_mae: 0.3585
# processing fold # 2
# Epoch 1/50
# 10/10 [==============================] - 4s 86ms/step - loss: 1.0003 - mae: 0.4789 - val_loss: 0.9082 - val_mae: 0.5113
# Epoch 2/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.7670 - mae: 0.4356 - val_loss: 0.7176 - val_mae: 0.3937
# Epoch 3/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.6373 - mae: 0.4245 - val_loss: 0.6290 - val_mae: 0.4436
# Epoch 4/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5285 - mae: 0.3992 - val_loss: 0.6056 - val_mae: 0.4557
# Epoch 5/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4938 - mae: 0.3915 - val_loss: 0.7183 - val_mae: 0.5432
# Epoch 6/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4806 - mae: 0.3812 - val_loss: 0.4780 - val_mae: 0.3683
# Epoch 7/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4529 - mae: 0.3883 - val_loss: 0.4921 - val_mae: 0.3211
# Epoch 8/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4315 - mae: 0.3568 - val_loss: 0.5270 - val_mae: 0.3519
# Epoch 9/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4039 - mae: 0.3260 - val_loss: 0.4911 - val_mae: 0.3418
# Epoch 10/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4239 - mae: 0.3516 - val_loss: 0.4448 - val_mae: 0.3383
# Epoch 11/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3829 - mae: 0.3257 - val_loss: 0.6025 - val_mae: 0.4718
# Epoch 12/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3882 - mae: 0.3384 - val_loss: 0.5358 - val_mae: 0.4367
# Epoch 13/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4077 - mae: 0.3593 - val_loss: 0.4525 - val_mae: 0.3374
# Epoch 14/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3930 - mae: 0.3480 - val_loss: 0.4497 - val_mae: 0.3368
# Epoch 15/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3611 - mae: 0.3181 - val_loss: 0.4920 - val_mae: 0.4334
# Epoch 16/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3849 - mae: 0.3577 - val_loss: 0.4574 - val_mae: 0.3712
# Epoch 17/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3593 - mae: 0.3229 - val_loss: 0.4658 - val_mae: 0.3427
# Epoch 18/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3663 - mae: 0.3228 - val_loss: 0.4257 - val_mae: 0.3392
# Epoch 19/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3617 - mae: 0.3271 - val_loss: 0.4461 - val_mae: 0.4094
# Epoch 20/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3731 - mae: 0.3568 - val_loss: 0.4313 - val_mae: 0.3504
# Epoch 21/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3419 - mae: 0.3212 - val_loss: 0.4172 - val_mae: 0.3458
# Epoch 22/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3572 - mae: 0.3391 - val_loss: 0.4616 - val_mae: 0.2885
# Epoch 23/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3489 - mae: 0.3047 - val_loss: 0.5594 - val_mae: 0.4649
# Epoch 24/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3728 - mae: 0.3467 - val_loss: 0.4205 - val_mae: 0.3324
# Epoch 25/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3248 - mae: 0.2985 - val_loss: 0.4284 - val_mae: 0.3460
# Epoch 26/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3572 - mae: 0.3448 - val_loss: 0.4954 - val_mae: 0.4207
# Epoch 27/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3574 - mae: 0.3455 - val_loss: 0.4390 - val_mae: 0.3528
# Epoch 28/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3292 - mae: 0.3173 - val_loss: 0.4651 - val_mae: 0.4016
# Epoch 29/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3304 - mae: 0.3168 - val_loss: 0.4736 - val_mae: 0.3851
# Epoch 30/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3385 - mae: 0.3229 - val_loss: 0.5704 - val_mae: 0.4518
# Epoch 31/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3528 - mae: 0.3495 - val_loss: 0.4210 - val_mae: 0.3213
# Epoch 32/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3249 - mae: 0.3090 - val_loss: 0.4761 - val_mae: 0.4170
# Epoch 33/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3308 - mae: 0.3226 - val_loss: 0.4200 - val_mae: 0.3271
# Epoch 34/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3327 - mae: 0.3268 - val_loss: 0.4320 - val_mae: 0.3575
# Epoch 35/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3186 - mae: 0.3008 - val_loss: 0.4532 - val_mae: 0.3642
# Epoch 36/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3097 - mae: 0.2970 - val_loss: 0.4124 - val_mae: 0.3243
# Epoch 37/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3326 - mae: 0.3372 - val_loss: 0.4427 - val_mae: 0.3501
# Epoch 38/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3143 - mae: 0.3150 - val_loss: 0.4390 - val_mae: 0.3528
# Epoch 39/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3229 - mae: 0.3196 - val_loss: 0.4353 - val_mae: 0.3187
# Epoch 40/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3136 - mae: 0.3025 - val_loss: 0.4256 - val_mae: 0.3640
# Epoch 41/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3090 - mae: 0.3189 - val_loss: 0.4448 - val_mae: 0.3515
# Epoch 42/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3186 - mae: 0.3164 - val_loss: 0.4360 - val_mae: 0.3729
# Epoch 43/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3047 - mae: 0.3058 - val_loss: 0.5189 - val_mae: 0.4507
# Epoch 44/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3255 - mae: 0.3371 - val_loss: 0.4707 - val_mae: 0.4214
# Epoch 45/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3132 - mae: 0.3245 - val_loss: 0.4156 - val_mae: 0.3429
# Epoch 46/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3039 - mae: 0.3054 - val_loss: 0.4175 - val_mae: 0.3256
# Epoch 47/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3135 - mae: 0.3194 - val_loss: 0.4089 - val_mae: 0.3283
# Epoch 48/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.2924 - mae: 0.2958 - val_loss: 0.4846 - val_mae: 0.3467
# Epoch 49/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2963 - mae: 0.2873 - val_loss: 0.4419 - val_mae: 0.3699
# Epoch 50/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3047 - mae: 0.3196 - val_loss: 0.4385 - val_mae: 0.3661
# processing fold # 3
# Epoch 1/50
# 10/10 [==============================] - 4s 85ms/step - loss: 1.1172 - mae: 0.5152 - val_loss: 0.7938 - val_mae: 0.4511
# Epoch 2/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.8179 - mae: 0.4476 - val_loss: 0.6309 - val_mae: 0.3377
# Epoch 3/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.6979 - mae: 0.4305 - val_loss: 0.5249 - val_mae: 0.3861
# Epoch 4/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.6034 - mae: 0.4321 - val_loss: 0.5127 - val_mae: 0.3441
# Epoch 5/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4985 - mae: 0.3443 - val_loss: 0.8002 - val_mae: 0.5997
# Epoch 6/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5484 - mae: 0.4289 - val_loss: 0.5162 - val_mae: 0.4431
# Epoch 7/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4909 - mae: 0.4107 - val_loss: 0.4428 - val_mae: 0.4136
# Epoch 8/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4684 - mae: 0.4006 - val_loss: 0.3787 - val_mae: 0.3283
# Epoch 9/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4512 - mae: 0.3913 - val_loss: 0.4192 - val_mae: 0.3081
# Epoch 10/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4094 - mae: 0.3257 - val_loss: 0.5729 - val_mae: 0.4614
# Epoch 11/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4735 - mae: 0.4139 - val_loss: 0.3885 - val_mae: 0.3623
# Epoch 12/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4030 - mae: 0.3702 - val_loss: 0.4360 - val_mae: 0.3776
# Epoch 13/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4093 - mae: 0.3627 - val_loss: 0.4591 - val_mae: 0.4087
# Epoch 14/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3955 - mae: 0.3571 - val_loss: 0.5688 - val_mae: 0.4816
# Epoch 15/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4178 - mae: 0.3824 - val_loss: 0.4047 - val_mae: 0.3698
# Epoch 16/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3909 - mae: 0.3575 - val_loss: 0.5206 - val_mae: 0.4429
# Epoch 17/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4017 - mae: 0.3631 - val_loss: 0.3726 - val_mae: 0.3448
# Epoch 18/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3885 - mae: 0.3672 - val_loss: 0.4170 - val_mae: 0.3933
# Epoch 19/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3550 - mae: 0.3339 - val_loss: 0.3898 - val_mae: 0.3512
# Epoch 20/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3744 - mae: 0.3501 - val_loss: 0.5171 - val_mae: 0.4359
# Epoch 21/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3742 - mae: 0.3539 - val_loss: 0.4171 - val_mae: 0.3891
# Epoch 22/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3637 - mae: 0.3529 - val_loss: 0.3638 - val_mae: 0.3134
# Epoch 23/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3669 - mae: 0.3426 - val_loss: 0.3938 - val_mae: 0.3050
# Epoch 24/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3522 - mae: 0.3167 - val_loss: 0.5328 - val_mae: 0.4623
# Epoch 25/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3816 - mae: 0.3477 - val_loss: 0.4600 - val_mae: 0.4105
# Epoch 26/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3557 - mae: 0.3442 - val_loss: 0.3796 - val_mae: 0.3354
# Epoch 27/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3535 - mae: 0.3352 - val_loss: 0.3842 - val_mae: 0.3309
# Epoch 28/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3341 - mae: 0.3068 - val_loss: 0.6799 - val_mae: 0.5621
# Epoch 29/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3998 - mae: 0.3785 - val_loss: 0.4063 - val_mae: 0.3619
# Epoch 30/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3311 - mae: 0.3111 - val_loss: 0.3918 - val_mae: 0.3531
# Epoch 31/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3551 - mae: 0.3415 - val_loss: 0.3892 - val_mae: 0.3358
# Epoch 32/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3459 - mae: 0.3295 - val_loss: 0.3604 - val_mae: 0.3392
# Epoch 33/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3408 - mae: 0.3325 - val_loss: 0.4833 - val_mae: 0.4153
# Epoch 34/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3441 - mae: 0.3386 - val_loss: 0.4184 - val_mae: 0.3899
# Epoch 35/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3179 - mae: 0.3204 - val_loss: 0.4347 - val_mae: 0.3988
# Epoch 36/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3500 - mae: 0.3481 - val_loss: 0.5241 - val_mae: 0.4713
# Epoch 37/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3372 - mae: 0.3403 - val_loss: 0.6450 - val_mae: 0.4996
# Epoch 38/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3625 - mae: 0.3704 - val_loss: 0.3822 - val_mae: 0.3484
# Epoch 39/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3247 - mae: 0.3277 - val_loss: 0.4001 - val_mae: 0.3655
# Epoch 40/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3276 - mae: 0.3296 - val_loss: 0.4172 - val_mae: 0.3980
# Epoch 41/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3238 - mae: 0.3231 - val_loss: 0.3986 - val_mae: 0.3722
# Epoch 42/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3157 - mae: 0.3145 - val_loss: 0.5288 - val_mae: 0.4732
# Epoch 43/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3429 - mae: 0.3502 - val_loss: 0.3778 - val_mae: 0.3439
# Epoch 44/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3156 - mae: 0.3255 - val_loss: 0.4015 - val_mae: 0.3560
# Epoch 45/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3089 - mae: 0.3034 - val_loss: 0.4088 - val_mae: 0.3735
# Epoch 46/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3335 - mae: 0.3334 - val_loss: 0.4798 - val_mae: 0.4511
# Epoch 47/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3218 - mae: 0.3270 - val_loss: 0.4549 - val_mae: 0.4184
# Epoch 48/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3215 - mae: 0.3230 - val_loss: 0.4334 - val_mae: 0.4057
# Epoch 49/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3168 - mae: 0.3307 - val_loss: 0.5217 - val_mae: 0.4550
# Epoch 50/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3227 - mae: 0.3408 - val_loss: 0.4625 - val_mae: 0.4167
# processing fold # 4
# Epoch 1/50
# 10/10 [==============================] - 4s 86ms/step - loss: 1.0041 - mae: 0.4760 - val_loss: 0.8264 - val_mae: 0.3583
# Epoch 2/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.7871 - mae: 0.4203 - val_loss: 0.7553 - val_mae: 0.4207
# Epoch 3/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.6585 - mae: 0.4179 - val_loss: 0.6572 - val_mae: 0.4353
# Epoch 4/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.5653 - mae: 0.4110 - val_loss: 0.5721 - val_mae: 0.4477
# Epoch 5/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5269 - mae: 0.4182 - val_loss: 0.5108 - val_mae: 0.3554
# Epoch 6/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4527 - mae: 0.3584 - val_loss: 0.5140 - val_mae: 0.3629
# Epoch 7/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4251 - mae: 0.3316 - val_loss: 0.4888 - val_mae: 0.3424
# Epoch 8/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4435 - mae: 0.3773 - val_loss: 0.4701 - val_mae: 0.3924
# Epoch 9/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.4303 - mae: 0.3770 - val_loss: 0.4446 - val_mae: 0.3563
# Epoch 10/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3920 - mae: 0.3459 - val_loss: 0.5583 - val_mae: 0.3925
# Epoch 11/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3893 - mae: 0.3200 - val_loss: 0.4626 - val_mae: 0.3402
# Epoch 12/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4110 - mae: 0.3644 - val_loss: 0.4629 - val_mae: 0.3608
# Epoch 13/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3815 - mae: 0.3343 - val_loss: 0.4935 - val_mae: 0.3629
# Epoch 14/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3908 - mae: 0.3488 - val_loss: 0.5072 - val_mae: 0.3152
# Epoch 15/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3641 - mae: 0.3075 - val_loss: 0.5433 - val_mae: 0.4260
# Epoch 16/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3987 - mae: 0.3643 - val_loss: 0.4968 - val_mae: 0.3974
# Epoch 17/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3651 - mae: 0.3432 - val_loss: 0.4425 - val_mae: 0.3157
# Epoch 18/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3419 - mae: 0.3049 - val_loss: 0.5568 - val_mae: 0.4419
# Epoch 19/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.3690 - mae: 0.3368 - val_loss: 0.4487 - val_mae: 0.3095
# Epoch 20/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.3721 - mae: 0.3489 - val_loss: 0.4763 - val_mae: 0.4052
# Epoch 21/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3516 - mae: 0.3318 - val_loss: 0.5039 - val_mae: 0.4203
# Epoch 22/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3510 - mae: 0.3329 - val_loss: 0.4480 - val_mae: 0.3758
# Epoch 23/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3522 - mae: 0.3387 - val_loss: 0.4830 - val_mae: 0.3958
# Epoch 24/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3441 - mae: 0.3244 - val_loss: 0.4619 - val_mae: 0.3732
# Epoch 25/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3470 - mae: 0.3317 - val_loss: 0.4604 - val_mae: 0.4016
# Epoch 26/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3350 - mae: 0.3342 - val_loss: 0.4378 - val_mae: 0.3020
# Epoch 27/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3404 - mae: 0.3173 - val_loss: 0.4411 - val_mae: 0.3537
# Epoch 28/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3397 - mae: 0.3367 - val_loss: 0.4629 - val_mae: 0.3257
# Epoch 29/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3228 - mae: 0.3018 - val_loss: 0.4603 - val_mae: 0.3652
# Epoch 30/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3267 - mae: 0.3148 - val_loss: 0.5025 - val_mae: 0.4106
# Epoch 31/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3274 - mae: 0.3214 - val_loss: 0.4410 - val_mae: 0.3175
# Epoch 32/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3288 - mae: 0.3136 - val_loss: 0.4638 - val_mae: 0.4215
# Epoch 33/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3224 - mae: 0.3286 - val_loss: 0.5833 - val_mae: 0.4851
# Epoch 34/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3437 - mae: 0.3360 - val_loss: 0.4345 - val_mae: 0.3388
# Epoch 35/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3265 - mae: 0.3241 - val_loss: 0.4559 - val_mae: 0.3848
# Epoch 36/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3060 - mae: 0.3100 - val_loss: 0.4609 - val_mae: 0.3671
# Epoch 37/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3315 - mae: 0.3333 - val_loss: 0.4279 - val_mae: 0.3218
# Epoch 38/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.3005 - mae: 0.2940 - val_loss: 0.4415 - val_mae: 0.3668
# Epoch 39/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3300 - mae: 0.3369 - val_loss: 0.4280 - val_mae: 0.3586
# Epoch 40/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.2988 - mae: 0.3025 - val_loss: 0.4369 - val_mae: 0.3158
# Epoch 41/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3286 - mae: 0.3230 - val_loss: 0.4392 - val_mae: 0.3664
# Epoch 42/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3038 - mae: 0.3126 - val_loss: 0.4506 - val_mae: 0.3592
# Epoch 43/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.3000 - mae: 0.2998 - val_loss: 0.5070 - val_mae: 0.4264
# Epoch 44/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3152 - mae: 0.3184 - val_loss: 0.4740 - val_mae: 0.3040
# Epoch 45/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3158 - mae: 0.3038 - val_loss: 0.4401 - val_mae: 0.3875
# Epoch 46/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3035 - mae: 0.3213 - val_loss: 0.4339 - val_mae: 0.3522
# Epoch 47/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3049 - mae: 0.3178 - val_loss: 0.4364 - val_mae: 0.3529
# Epoch 48/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.2934 - mae: 0.2980 - val_loss: 0.4437 - val_mae: 0.3569
# Epoch 49/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.2987 - mae: 0.3089 - val_loss: 0.4346 - val_mae: 0.3149
# Epoch 50/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.2954 - mae: 0.2955 - val_loss: 0.4708 - val_mae: 0.4029

# %%
# Calculate the average accuracy acorss validations.
average_train_history = [
    np.mean([x[i] for x in  all_train_histories]) for i in range(num_epochs)]

average_val_history = [
    np.mean([x[i] for x in all_val_histories]) for i in range(num_epochs)]

# %%
# Define a function to smooth the history of loss.
def smooth_curve(points, factor=0.9):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)
  return smoothed_points

# %%
smooth_history1 = smooth_curve(average_train_history[10:])
smooth_history2 = smooth_curve(average_val_history[10:])

# Plot the smmoothed history.
plt.plot(range(1, len(smooth_history1) + 1), smooth_history1, label = 'training')
plt.plot(range(1, len(smooth_history2) + 1), smooth_history2, label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
train_data = create_data(x_train)
test_data = create_data(x_test)

# Train the final model.
model = build_model(cat_col, cat_col_name, embedding_dim)
model.fit(
    train_data,
    {"prediction": y_train[:, -1]},
    epochs=50,
    batch_size=1000)

# Print out the final results.
model.evaluate(train_data, y_train[:, -1])
model.evaluate(test_data, y_test[:, -1])
# Out:
# Epoch 1/50
# 13/13 [==============================] - 3s 14ms/step - loss: 0.9810 - mae: 0.4444
# Epoch 2/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.7288 - mae: 0.4360
# Epoch 3/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.5763 - mae: 0.4075
# Epoch 4/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.5240 - mae: 0.3957
# Epoch 5/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.4705 - mae: 0.3911
# Epoch 6/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.4434 - mae: 0.3687
# Epoch 7/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.4403 - mae: 0.3624
# Epoch 8/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.4151 - mae: 0.3556
# Epoch 9/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.4182 - mae: 0.3582
# Epoch 10/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3993 - mae: 0.3480
# Epoch 11/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3901 - mae: 0.3473
# Epoch 12/50
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3779 - mae: 0.3276
# Epoch 13/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3804 - mae: 0.3381
# Epoch 14/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3866 - mae: 0.3493
# Epoch 15/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3785 - mae: 0.3413
# Epoch 16/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3722 - mae: 0.3367
# Epoch 17/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3697 - mae: 0.3390
# Epoch 18/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3634 - mae: 0.3287
# Epoch 19/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3596 - mae: 0.3182
# Epoch 20/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3514 - mae: 0.3251
# Epoch 21/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3509 - mae: 0.3245
# Epoch 22/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3594 - mae: 0.3315
# Epoch 23/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3494 - mae: 0.3334
# Epoch 24/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3549 - mae: 0.3424
# Epoch 25/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3481 - mae: 0.3286
# Epoch 26/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3382 - mae: 0.3194
# Epoch 27/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3335 - mae: 0.3214
# Epoch 28/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3457 - mae: 0.3313
# Epoch 29/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3358 - mae: 0.3220
# Epoch 30/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3343 - mae: 0.3292
# Epoch 31/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3373 - mae: 0.3322
# Epoch 32/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3334 - mae: 0.3226
# Epoch 33/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3371 - mae: 0.3228
# Epoch 34/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3281 - mae: 0.3232
# Epoch 35/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3282 - mae: 0.3202
# Epoch 36/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3195 - mae: 0.3099
# Epoch 37/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3212 - mae: 0.3197
# Epoch 38/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3301 - mae: 0.3301
# Epoch 39/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3198 - mae: 0.3159
# Epoch 40/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3200 - mae: 0.3044
# Epoch 41/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3245 - mae: 0.3262
# Epoch 42/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3155 - mae: 0.3103
# Epoch 43/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3218 - mae: 0.3160
# Epoch 44/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3112 - mae: 0.3083
# Epoch 45/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3192 - mae: 0.3309
# Epoch 46/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3105 - mae: 0.3104
# Epoch 47/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3029 - mae: 0.2971
# Epoch 48/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3048 - mae: 0.3105
# Epoch 49/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3173 - mae: 0.3114
# Epoch 50/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2947 - mae: 0.2989
# 377/377 [==============================] - 2s 3ms/step - loss: 0.3047 - mae: 0.2842
# 95/95 [==============================] - 1s 4ms/step - loss: 0.3271 - mae: 0.3080
# [0.3271307647228241, 0.30797427892684937]
